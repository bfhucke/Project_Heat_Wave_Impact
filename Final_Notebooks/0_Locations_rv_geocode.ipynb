# %% [markdown]
# # Reverse Geocoding to obtain country and NUTS from coordinates

# %%
# load relevant libraries
import xarray as xr
import pandas as pd
import numpy as np
# Out:
# C:\Users\benhu\anaconda3\lib\site-packages\xarray\backends\cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %%
# open raw data and transform to pandas df
ds = xr.open_dataset('C:/Users/benhu/MasterThesisRawData/download18_21.nc')
df = ds.to_dataframe()
# Out:
# C:\Users\benhu\anaconda3\lib\site-packages\xarray\backends\plugins.py:61: RuntimeWarning: Engine 'cfgrib' loading failed:
# ecCodes library not found using ['eccodes', 'libeccodes.so', 'libeccodes']
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
# get coordinates and time as variables
df = df.reset_index(level=['longitude', 'latitude', 'time'])
df
# Out:
#           longitude  latitude                time        u10         d2m  \
# 0             -10.0      71.0 2018-05-01 02:00:00  -6.397677  274.760529
# 1             -10.0      71.0 2018-05-01 11:00:00 -10.199122  273.712616
# 2             -10.0      71.0 2018-05-01 16:00:00 -11.301038  273.334991
# 3             -10.0      71.0 2018-05-01 23:00:00 -12.028891  274.409027
# 4             -10.0      71.0 2018-05-02 02:00:00 -10.598689  274.831635
# ...             ...       ...                 ...        ...         ...
# 53995531       30.0      37.0 2021-09-29 23:00:00   0.064060  276.603729
# 53995532       30.0      37.0 2021-09-30 02:00:00   0.652620  278.227905
# 53995533       30.0      37.0 2021-09-30 11:00:00  -0.249185  278.330078
# 53995534       30.0      37.0 2021-09-30 16:00:00  -1.631648  278.479675
# 53995535       30.0      37.0 2021-09-30 23:00:00  -1.016929  278.456787
#
#                  t2m            uvb
# 0         276.599854       0.000000
# 1         276.260498  118736.773438
# 2         276.105469  110801.500000
# 3         276.233093      55.687500
# 4         276.350311       0.000000
# ...              ...            ...
# 53995531  287.014404       0.000000
# 53995532  285.402771       0.000000
# 53995533  293.606445  211349.796875
# 53995534  291.566620    7524.593750
# 53995535  283.995331       0.000000
#
# [53995536 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53995536 entries, 0 to 53995535
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   longitude  float64
#  1   latitude   float64
#  2   time       datetime64[ns]
#  3   u10        float32
#  4   d2m        float32
#  5   t2m        float32
#  6   uvb        float32
# dtypes: datetime64[ns](1), float32(4), float64(2)
# memory usage: 2.0 GB

# %%
# specify coordinates range for Europe to filter 
lon = list(np.arange(-10, 31, 0.75))
lat = list(np.arange(37, 72, 0.75))

# %%
# subset data to coordinates of Europe
df = df[df['longitude'].isin(lon) & df['latitude'].isin(lat)]

# %%
# inspect shape --> 1/9th of the original data
df.shape
# Out:
# (6080832, 7)

# %%
# transform coordinates to string
df['lat'] = df['latitude'].astype(str)
df['lon'] = df['longitude'].astype(str)
# Out:
# <ipython-input-9-522575cd2e00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lat'] = df['latitude'].astype(str)
# <ipython-input-9-522575cd2e00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lon'] = df['longitude'].astype(str)

# %%
# get column that adds coordinates together
df['lat_long'] = df[['lat', 'lon']].apply(tuple, axis=1)
# Out:
# <ipython-input-10-6e67aed85db5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lat_long'] = df[['lat', 'lon']].apply(tuple, axis=1)

# %%
# drop duplicates to have one instance representing one unique location
df = df.drop_duplicates(subset=['lat_long'], keep='first')

# %%
df
# Out:
#           longitude  latitude                time       u10         d2m  \
# 0            -10.00     71.00 2018-05-01 02:00:00 -6.397677  274.760529
# 7344         -10.00     70.25 2018-05-01 02:00:00 -6.526506  275.174927
# 14688        -10.00     69.50 2018-05-01 02:00:00 -6.965965  275.057220
# 22032        -10.00     68.75 2018-05-01 02:00:00 -7.714090  274.774414
# 29376        -10.00     68.00 2018-05-01 02:00:00 -8.437366  274.559448
# ...             ...       ...                 ...       ...         ...
# 53625888      29.75     40.25 2018-05-01 02:00:00 -0.704992  282.959808
# 53633232      29.75     39.50 2018-05-01 02:00:00 -0.580741  277.455475
# 53640576      29.75     38.75 2018-05-01 02:00:00 -1.340637  273.789459
# 53647920      29.75     38.00 2018-05-01 02:00:00 -0.574201  278.682373
# 53655264      29.75     37.25 2018-05-01 02:00:00  0.495016  280.619598
#
#                  t2m  uvb    lat    lon        lat_long
# 0         276.599854  0.0   71.0  -10.0   (71.0, -10.0)
# 7344      277.215179  0.0  70.25  -10.0  (70.25, -10.0)
# 14688     277.189667  0.0   69.5  -10.0   (69.5, -10.0)
# 22032     276.953369  0.0  68.75  -10.0  (68.75, -10.0)
# 29376     276.742554  0.0   68.0  -10.0   (68.0, -10.0)
# ...              ...  ...    ...    ...             ...
# 53625888  284.051086  0.0  40.25  29.75  (40.25, 29.75)
# 53633232  284.869659  0.0   39.5  29.75   (39.5, 29.75)
# 53640576  281.447937  0.0  38.75  29.75  (38.75, 29.75)
# 53647920  288.373627  0.0   38.0  29.75   (38.0, 29.75)
# 53655264  285.615448  0.0  37.25  29.75  (37.25, 29.75)
#
# [2484 rows x 10 columns]

# %%
lati = df['latitude']
long = df['longitude']

# %%
# import nuts_finder as a reverse geocoding library
import nuts_finder

# %%
# loop over coordinates to identify locations
nf = nuts_finder.NutsFinder()
nuts = []
for lat, lon in zip(df['latitude'],df['longitude']):
    a = nf.find(lat, lon)
    nuts.append(a)

# %%
# inspect results
nuts
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE05',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Southern',
#    'NUTS_NAME': 'Southern',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE05'},
#   {'NUTS_ID': 'IE053',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'South-West',
#    'NUTS_NAME': 'South-West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE053'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE04',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Northern and Western',
#    'NUTS_NAME': 'Northern and Western',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE04'},
#   {'NUTS_ID': 'IE042',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'West',
#    'NUTS_NAME': 'West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE042'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE05',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Southern',
#    'NUTS_NAME': 'Southern',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE05'},
#   {'NUTS_ID': 'IE051',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Mid-West',
#    'NUTS_NAME': 'Mid-West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE051'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE05',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Southern',
#    'NUTS_NAME': 'Southern',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE05'},
#   {'NUTS_ID': 'IE053',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'South-West',
#    'NUTS_NAME': 'South-West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE053'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT17',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Área Metropolitana de Lisboa',
#    'NUTS_NAME': 'Área Metropolitana de Lisboa',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT17'},
#   {'NUTS_ID': 'PT170',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Área Metropolitana de Lisboa',
#    'NUTS_NAME': 'Área Metropolitana de Lisboa',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 1,
#    'COAST_TYPE': 1,
#    'FID': 'PT170'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE04',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Northern and Western',
#    'NUTS_NAME': 'Northern and Western',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE04'},
#   {'NUTS_ID': 'IE042',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'West',
#    'NUTS_NAME': 'West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE042'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE04',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Northern and Western',
#    'NUTS_NAME': 'Northern and Western',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE04'},
#   {'NUTS_ID': 'IE042',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'West',
#    'NUTS_NAME': 'West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE042'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE05',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Southern',
#    'NUTS_NAME': 'Southern',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE05'},
#   {'NUTS_ID': 'IE053',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'South-West',
#    'NUTS_NAME': 'South-West',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE053'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Galicia',
#    'NUTS_NAME': 'Galicia',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES11'},
#   {'NUTS_ID': 'ES111',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'A Coruña',
#    'NUTS_NAME': 'A Coruña',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'ES111'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Galicia',
#    'NUTS_NAME': 'Galicia',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES11'},
#   {'NUTS_ID': 'ES114',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Pontevedra',
#    'NUTS_NAME': 'Pontevedra',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'ES114'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Norte',
#    'NUTS_NAME': 'Norte',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT11'},
#   {'NUTS_ID': 'PT111',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alto Minho',
#    'NUTS_NAME': 'Alto Minho',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'PT111'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Norte',
#    'NUTS_NAME': 'Norte',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT11'},
#   {'NUTS_ID': 'PT11A',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Área Metropolitana do Porto',
#    'NUTS_NAME': 'Área Metropolitana do Porto',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 1,
#    'COAST_TYPE': 1,
#    'FID': 'PT11A'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT16',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Centro (PT)',
#    'NUTS_NAME': 'Centro (PT)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT16'},
#   {'NUTS_ID': 'PT16E',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Região de Coimbra',
#    'NUTS_NAME': 'Região de Coimbra',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'PT16E'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT16',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Centro (PT)',
#    'NUTS_NAME': 'Centro (PT)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT16'},
#   {'NUTS_ID': 'PT16I',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Médio Tejo',
#    'NUTS_NAME': 'Médio Tejo',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT16I'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT18',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo',
#    'NUTS_NAME': 'Alentejo',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT18'},
#   {'NUTS_ID': 'PT187',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo Central',
#    'NUTS_NAME': 'Alentejo Central',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT187'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT18',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo',
#    'NUTS_NAME': 'Alentejo',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT18'},
#   {'NUTS_ID': 'PT181',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo Litoral',
#    'NUTS_NAME': 'Alentejo Litoral',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'PT181'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT15',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Algarve',
#    'NUTS_NAME': 'Algarve',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT15'},
#   {'NUTS_ID': 'PT150',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Algarve',
#    'NUTS_NAME': 'Algarve',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'PT150'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'UK',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'United Kingdom',
#    'NUTS_NAME': 'United Kingdom',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UK'},
#   {'NUTS_ID': 'UKN',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Northern Ireland',
#    'NUTS_NAME': 'Northern Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKN'},
#   {'NUTS_ID': 'UKN0',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Northern Ireland',
#    'NUTS_NAME': 'Northern Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKN0'},
#   {'NUTS_ID': 'UKN0G',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Fermanagh and Omagh',
#    'NUTS_NAME': 'Fermanagh and Omagh',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 2,
#    'FID': 'UKN0G'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE06',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Eastern and Midland',
#    'NUTS_NAME': 'Eastern and Midland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE06'},
#   {'NUTS_ID': 'IE063',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Midland',
#    'NUTS_NAME': 'Midland',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'IE063'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE06',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Eastern and Midland',
#    'NUTS_NAME': 'Eastern and Midland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE06'},
#   {'NUTS_ID': 'IE063',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Midland',
#    'NUTS_NAME': 'Midland',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'IE063'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE05',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Southern',
#    'NUTS_NAME': 'Southern',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE05'},
#   {'NUTS_ID': 'IE052',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'South-East',
#    'NUTS_NAME': 'South-East',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE052'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Galicia',
#    'NUTS_NAME': 'Galicia',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES11'},
#   {'NUTS_ID': 'ES112',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Lugo',
#    'NUTS_NAME': 'Lugo',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'ES112'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Galicia',
#    'NUTS_NAME': 'Galicia',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES11'},
#   {'NUTS_ID': 'ES112',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Lugo',
#    'NUTS_NAME': 'Lugo',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'ES112'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Norte',
#    'NUTS_NAME': 'Norte',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT11'},
#   {'NUTS_ID': 'PT11B',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alto Tâmega',
#    'NUTS_NAME': 'Alto Tâmega',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT11B'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Norte',
#    'NUTS_NAME': 'Norte',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT11'},
#   {'NUTS_ID': 'PT11D',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Douro',
#    'NUTS_NAME': 'Douro',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT11D'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT16',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Centro (PT)',
#    'NUTS_NAME': 'Centro (PT)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT16'},
#   {'NUTS_ID': 'PT16J',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Beiras e Serra da Estrela',
#    'NUTS_NAME': 'Beiras e Serra da Estrela',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT16J'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT18',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo',
#    'NUTS_NAME': 'Alentejo',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT18'},
#   {'NUTS_ID': 'PT186',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alto Alentejo',
#    'NUTS_NAME': 'Alto Alentejo',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT186'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT18',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo',
#    'NUTS_NAME': 'Alentejo',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT18'},
#   {'NUTS_ID': 'PT187',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo Central',
#    'NUTS_NAME': 'Alentejo Central',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT187'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT18',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Alentejo',
#    'NUTS_NAME': 'Alentejo',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT18'},
#   {'NUTS_ID': 'PT184',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Baixo Alentejo',
#    'NUTS_NAME': 'Baixo Alentejo',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT184'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT15',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Algarve',
#    'NUTS_NAME': 'Algarve',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT15'},
#   {'NUTS_ID': 'PT150',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Algarve',
#    'NUTS_NAME': 'Algarve',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'PT150'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'UK',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'United Kingdom',
#    'NUTS_NAME': 'United Kingdom',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UK'},
#   {'NUTS_ID': 'UKN',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Northern Ireland',
#    'NUTS_NAME': 'Northern Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKN'},
#   {'NUTS_ID': 'UKN0',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Northern Ireland',
#    'NUTS_NAME': 'Northern Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKN0'},
#   {'NUTS_ID': 'UKN0B',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Mid Ulster',
#    'NUTS_NAME': 'Mid Ulster',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 2,
#    'FID': 'UKN0B'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE06',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Eastern and Midland',
#    'NUTS_NAME': 'Eastern and Midland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE06'},
#   {'NUTS_ID': 'IE062',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Mid-East',
#    'NUTS_NAME': 'Mid-East',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'IE062'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE06',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Eastern and Midland',
#    'NUTS_NAME': 'Eastern and Midland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE06'},
#   {'NUTS_ID': 'IE062',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Mid-East',
#    'NUTS_NAME': 'Mid-East',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'IE062'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE05',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Southern',
#    'NUTS_NAME': 'Southern',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE05'},
#   {'NUTS_ID': 'IE052',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'South-East',
#    'NUTS_NAME': 'South-East',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'IE052'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES12',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Principado de Asturias',
#    'NUTS_NAME': 'Principado de Asturias',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES12'},
#   {'NUTS_ID': 'ES120',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Asturias',
#    'NUTS_NAME': 'Asturias',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'ES120'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Galicia',
#    'NUTS_NAME': 'Galicia',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES11'},
#   {'NUTS_ID': 'ES113',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Ourense',
#    'NUTS_NAME': 'Ourense',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'ES113'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Norte',
#    'NUTS_NAME': 'Norte',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT11'},
#   {'NUTS_ID': 'PT11E',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Terras de Trás-os-Montes',
#    'NUTS_NAME': 'Terras de Trás-os-Montes',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT11E'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT11',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Norte',
#    'NUTS_NAME': 'Norte',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT11'},
#   {'NUTS_ID': 'PT11D',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Douro',
#    'NUTS_NAME': 'Douro',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT11D'}],
#  [{'NUTS_ID': 'PT',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Portugal',
#    'NUTS_NAME': 'Portugal',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT'},
#   {'NUTS_ID': 'PT1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Continente',
#    'NUTS_NAME': 'Continente',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT1'},
#   {'NUTS_ID': 'PT16',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Centro (PT)',
#    'NUTS_NAME': 'Centro (PT)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'PT16'},
#   {'NUTS_ID': 'PT16H',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'PT',
#    'NAME_LATN': 'Beira Baixa',
#    'NUTS_NAME': 'Beira Baixa',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'PT16H'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES43',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Extremadura',
#    'NUTS_NAME': 'Extremadura',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES43'},
#   {'NUTS_ID': 'ES432',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Cáceres',
#    'NUTS_NAME': 'Cáceres',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES432'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES43',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Extremadura',
#    'NUTS_NAME': 'Extremadura',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES43'},
#   {'NUTS_ID': 'ES431',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Badajoz',
#    'NUTS_NAME': 'Badajoz',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES431'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES6',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Sur',
#    'NUTS_NAME': 'Sur',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES6'},
#   {'NUTS_ID': 'ES61',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Andalucía',
#    'NUTS_NAME': 'Andalucía',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES61'},
#   {'NUTS_ID': 'ES615',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Huelva',
#    'NUTS_NAME': 'Huelva',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'ES615'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES6',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Sur',
#    'NUTS_NAME': 'Sur',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES6'},
#   {'NUTS_ID': 'ES61',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Andalucía',
#    'NUTS_NAME': 'Andalucía',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES61'},
#   {'NUTS_ID': 'ES615',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Huelva',
#    'NUTS_NAME': 'Huelva',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'ES615'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'UK',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'United Kingdom',
#    'NUTS_NAME': 'United Kingdom',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UK'},
#   {'NUTS_ID': 'UKM',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Scotland',
#    'NUTS_NAME': 'Scotland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKM'},
#   {'NUTS_ID': 'UKM6',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Highlands and Islands',
#    'NUTS_NAME': 'Highlands and Islands',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKM6'},
#   {'NUTS_ID': 'UKM63',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Lochaber, Skye & Lochalsh, Arran & Cumbrae and Argyll & Bute',
#    'NUTS_NAME': 'Lochaber, Skye & Lochalsh, Arran & Cumbrae and Argyll & Bute',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'UKM63'}],
#  [],
#  [{'NUTS_ID': 'UK',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'United Kingdom',
#    'NUTS_NAME': 'United Kingdom',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UK'},
#   {'NUTS_ID': 'UKM',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Scotland',
#    'NUTS_NAME': 'Scotland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKM'},
#   {'NUTS_ID': 'UKM6',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Highlands and Islands',
#    'NUTS_NAME': 'Highlands and Islands',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKM6'},
#   {'NUTS_ID': 'UKM63',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Lochaber, Skye & Lochalsh, Arran & Cumbrae and Argyll & Bute',
#    'NUTS_NAME': 'Lochaber, Skye & Lochalsh, Arran & Cumbrae and Argyll & Bute',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'UKM63'}],
#  [],
#  [{'NUTS_ID': 'UK',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'United Kingdom',
#    'NUTS_NAME': 'United Kingdom',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UK'},
#   {'NUTS_ID': 'UKN',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Northern Ireland',
#    'NUTS_NAME': 'Northern Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKN'},
#   {'NUTS_ID': 'UKN0',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Northern Ireland',
#    'NUTS_NAME': 'Northern Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKN0'},
#   {'NUTS_ID': 'UKN0E',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Lisburn and Castlereagh',
#    'NUTS_NAME': 'Lisburn and Castlereagh',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 2,
#    'FID': 'UKN0E'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE06',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Eastern and Midland',
#    'NUTS_NAME': 'Eastern and Midland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE06'},
#   {'NUTS_ID': 'IE062',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Mid-East',
#    'NUTS_NAME': 'Mid-East',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'IE062'}],
#  [{'NUTS_ID': 'IE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Éire/Ireland',
#    'NUTS_NAME': 'Éire/Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE'},
#   {'NUTS_ID': 'IE0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Ireland',
#    'NUTS_NAME': 'Ireland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE0'},
#   {'NUTS_ID': 'IE06',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Eastern and Midland',
#    'NUTS_NAME': 'Eastern and Midland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'IE06'},
#   {'NUTS_ID': 'IE062',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'IE',
#    'NAME_LATN': 'Mid-East',
#    'NUTS_NAME': 'Mid-East',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'IE062'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Noroeste',
#    'NUTS_NAME': 'Noroeste',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES1'},
#   {'NUTS_ID': 'ES12',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Principado de Asturias',
#    'NUTS_NAME': 'Principado de Asturias',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES12'},
#   {'NUTS_ID': 'ES120',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Asturias',
#    'NUTS_NAME': 'Asturias',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'ES120'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES41',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Castilla y León',
#    'NUTS_NAME': 'Castilla y León',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES41'},
#   {'NUTS_ID': 'ES413',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'León',
#    'NUTS_NAME': 'León',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES413'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES41',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Castilla y León',
#    'NUTS_NAME': 'Castilla y León',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES41'},
#   {'NUTS_ID': 'ES419',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Zamora',
#    'NUTS_NAME': 'Zamora',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'ES419'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES41',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Castilla y León',
#    'NUTS_NAME': 'Castilla y León',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES41'},
#   {'NUTS_ID': 'ES415',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Salamanca',
#    'NUTS_NAME': 'Salamanca',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES415'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES43',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Extremadura',
#    'NUTS_NAME': 'Extremadura',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES43'},
#   {'NUTS_ID': 'ES432',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Cáceres',
#    'NUTS_NAME': 'Cáceres',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES432'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES43',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Extremadura',
#    'NUTS_NAME': 'Extremadura',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES43'},
#   {'NUTS_ID': 'ES432',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Cáceres',
#    'NUTS_NAME': 'Cáceres',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES432'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES43',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Extremadura',
#    'NUTS_NAME': 'Extremadura',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES43'},
#   {'NUTS_ID': 'ES431',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Badajoz',
#    'NUTS_NAME': 'Badajoz',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES431'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Centro (ES)',
#    'NUTS_NAME': 'Centro (ES)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES4'},
#   {'NUTS_ID': 'ES43',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Extremadura',
#    'NUTS_NAME': 'Extremadura',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES43'},
#   {'NUTS_ID': 'ES431',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Badajoz',
#    'NUTS_NAME': 'Badajoz',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'ES431'}],
#  [{'NUTS_ID': 'ES',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'España',
#    'NUTS_NAME': 'España',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES'},
#   {'NUTS_ID': 'ES6',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Sur',
#    'NUTS_NAME': 'Sur',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES6'},
#   {'NUTS_ID': 'ES61',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Andalucía',
#    'NUTS_NAME': 'Andalucía',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'ES61'},
#   {'NUTS_ID': 'ES618',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'ES',
#    'NAME_LATN': 'Sevilla',
#    'NUTS_NAME': 'Sevilla',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 1,
#    'COAST_TYPE': 3,
#    'FID': 'ES618'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'UK',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'United Kingdom',
#    'NUTS_NAME': 'United Kingdom',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UK'},
#   {'NUTS_ID': 'UKM',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'UK',
#    'NAME_LATN': 'Scotland',
#    'NUTS_NAME': 'Scotland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'UKM'},
#   {'NUTS_ID': 'UKM6',
# ...
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF2'},
#   {'NUTS_ID': 'FRF24',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Haute-Marne',
#    'NUTS_NAME': 'Haute-Marne',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRF24'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRF',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Grand Est',
#    'NUTS_NAME': 'Grand Est',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF'},
#   {'NUTS_ID': 'FRF2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Champagne-Ardenne',
#    'NUTS_NAME': 'Champagne-Ardenne',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF2'},
#   {'NUTS_ID': 'FRF24',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Haute-Marne',
#    'NUTS_NAME': 'Haute-Marne',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRF24'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRC',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Bourgogne-Franche-Comté',
#    'NUTS_NAME': 'Bourgogne-Franche-Comté',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRC'},
#   {'NUTS_ID': 'FRC1',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Bourgogne',
#    'NUTS_NAME': 'Bourgogne',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRC1'},
#   {'NUTS_ID': 'FRC11',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Côte-d’Or',
#    'NUTS_NAME': 'Côte-d’Or',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'FRC11'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRK',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Auvergne-Rhône-Alpes',
#    'NUTS_NAME': 'Auvergne-Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK'},
#   {'NUTS_ID': 'FRK2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Rhône-Alpes',
#    'NUTS_NAME': 'Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK2'},
#   {'NUTS_ID': 'FRK21',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Ain',
#    'NUTS_NAME': 'Ain',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRK21'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRK',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Auvergne-Rhône-Alpes',
#    'NUTS_NAME': 'Auvergne-Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK'},
#   {'NUTS_ID': 'FRK2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Rhône-Alpes',
#    'NUTS_NAME': 'Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK2'},
#   {'NUTS_ID': 'FRK24',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Isère',
#    'NUTS_NAME': 'Isère',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'FRK24'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRK',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Auvergne-Rhône-Alpes',
#    'NUTS_NAME': 'Auvergne-Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK'},
#   {'NUTS_ID': 'FRK2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Rhône-Alpes',
#    'NUTS_NAME': 'Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK2'},
#   {'NUTS_ID': 'FRK23',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Drôme',
#    'NUTS_NAME': 'Drôme',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRK23'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRL',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Provence-Alpes-Côte d’Azur',
#    'NUTS_NAME': 'Provence-Alpes-Côte d’Azur',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRL'},
#   {'NUTS_ID': 'FRL0',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Provence-Alpes-Côte d’Azur',
#    'NUTS_NAME': 'Provence-Alpes-Côte d’Azur',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRL0'},
#   {'NUTS_ID': 'FRL06',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Vaucluse',
#    'NUTS_NAME': 'Vaucluse',
#    'MOUNT_TYPE': 2,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'FRL06'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'NO',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Norge',
#    'NUTS_NAME': 'Norge',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NO'},
#   {'NUTS_ID': 'NO0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Norge',
#    'NUTS_NAME': 'Norge',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NO0'},
#   {'NUTS_ID': 'NO0A',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Vestlandet',
#    'NUTS_NAME': 'Vestlandet',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': 0,
#    'COAST_TYPE': 0,
#    'FID': 'NO0A'},
#   {'NUTS_ID': 'NO0A3',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Møre og Romsdal',
#    'NUTS_NAME': 'Møre og Romsdal',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 1,
#    'FID': 'NO0A3'}],
#  [{'NUTS_ID': 'NO',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Norge',
#    'NUTS_NAME': 'Norge',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NO'},
#   {'NUTS_ID': 'NO0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Norge',
#    'NUTS_NAME': 'Norge',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NO0'},
#   {'NUTS_ID': 'NO0A',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Vestlandet',
#    'NUTS_NAME': 'Vestlandet',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': 0,
#    'COAST_TYPE': 0,
#    'FID': 'NO0A'},
#   {'NUTS_ID': 'NO0A2',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Vestland',
#    'NUTS_NAME': 'Vestland',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'NO0A2'}],
#  [{'NUTS_ID': 'NO',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Norge',
#    'NUTS_NAME': 'Norge',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NO'},
#   {'NUTS_ID': 'NO0',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Norge',
#    'NUTS_NAME': 'Norge',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NO0'},
#   {'NUTS_ID': 'NO0A',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Vestlandet',
#    'NUTS_NAME': 'Vestlandet',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': 0,
#    'COAST_TYPE': 0,
#    'FID': 'NO0A'},
#   {'NUTS_ID': 'NO0A2',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'NO',
#    'NAME_LATN': 'Vestland',
#    'NUTS_NAME': 'Vestland',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'NO0A2'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'NUTS_ID': 'NL',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Nederland',
#    'NUTS_NAME': 'Nederland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL'},
#   {'NUTS_ID': 'NL1',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Noord-Nederland',
#    'NUTS_NAME': 'Noord-Nederland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL1'},
#   {'NUTS_ID': 'NL12',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Friesland (NL)',
#    'NUTS_NAME': 'Friesland (NL)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL12'},
#   {'NUTS_ID': 'NL125',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Zuidwest-Friesland',
#    'NUTS_NAME': 'Zuidwest-Friesland',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 1,
#    'FID': 'NL125'}],
#  [{'NUTS_ID': 'NL',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Nederland',
#    'NUTS_NAME': 'Nederland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL'},
#   {'NUTS_ID': 'NL2',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Oost-Nederland',
#    'NUTS_NAME': 'Oost-Nederland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL2'},
#   {'NUTS_ID': 'NL22',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Gelderland',
#    'NUTS_NAME': 'Gelderland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL22'},
#   {'NUTS_ID': 'NL221',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Veluwe',
#    'NUTS_NAME': 'Veluwe',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 1,
#    'COAST_TYPE': 3,
#    'FID': 'NL221'}],
#  [{'NUTS_ID': 'NL',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Nederland',
#    'NUTS_NAME': 'Nederland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL'},
#   {'NUTS_ID': 'NL4',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Zuid-Nederland',
#    'NUTS_NAME': 'Zuid-Nederland',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL4'},
#   {'NUTS_ID': 'NL41',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Noord-Brabant',
#    'NUTS_NAME': 'Noord-Brabant',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'NL41'},
#   {'NUTS_ID': 'NL414',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'NL',
#    'NAME_LATN': 'Zuidoost-Noord-Brabant',
#    'NUTS_NAME': 'Zuidoost-Noord-Brabant',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 1,
#    'COAST_TYPE': 3,
#    'FID': 'NL414'}],
#  [{'NUTS_ID': 'BE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Belgique/België',
#    'NUTS_NAME': 'Belgique/België',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'BE'},
#   {'NUTS_ID': 'BE2',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Vlaams Gewest',
#    'NUTS_NAME': 'Vlaams Gewest',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'BE2'},
#   {'NUTS_ID': 'BE22',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Prov. Limburg (BE)',
#    'NUTS_NAME': 'Prov. Limburg (BE)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'BE22'},
#   {'NUTS_ID': 'BE223',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Arr. Tongeren',
#    'NUTS_NAME': 'Arr. Tongeren',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'BE223'}],
#  [{'NUTS_ID': 'BE',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Belgique/België',
#    'NUTS_NAME': 'Belgique/België',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'BE'},
#   {'NUTS_ID': 'BE3',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Région wallonne',
#    'NUTS_NAME': 'Région wallonne',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'BE3'},
#   {'NUTS_ID': 'BE34',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Prov. Luxembourg (BE)',
#    'NUTS_NAME': 'Prov. Luxembourg (BE)',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'BE34'},
#   {'NUTS_ID': 'BE342',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'BE',
#    'NAME_LATN': 'Arr. Bastogne',
#    'NUTS_NAME': 'Arr. Bastogne',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'BE342'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRF',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Grand Est',
#    'NUTS_NAME': 'Grand Est',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF'},
#   {'NUTS_ID': 'FRF3',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Lorraine',
#    'NUTS_NAME': 'Lorraine',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF3'},
#   {'NUTS_ID': 'FRF31',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Meurthe-et-Moselle',
#    'NUTS_NAME': 'Meurthe-et-Moselle',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 2,
#    'COAST_TYPE': 3,
#    'FID': 'FRF31'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRF',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Grand Est',
#    'NUTS_NAME': 'Grand Est',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF'},
#   {'NUTS_ID': 'FRF3',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Lorraine',
#    'NUTS_NAME': 'Lorraine',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRF3'},
#   {'NUTS_ID': 'FRF32',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Meuse',
#    'NUTS_NAME': 'Meuse',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRF32'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRC',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Bourgogne-Franche-Comté',
#    'NUTS_NAME': 'Bourgogne-Franche-Comté',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRC'},
#   {'NUTS_ID': 'FRC2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Franche-Comté',
#    'NUTS_NAME': 'Franche-Comté',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRC2'},
#   {'NUTS_ID': 'FRC23',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Haute-Saône',
#    'NUTS_NAME': 'Haute-Saône',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRC23'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRC',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Bourgogne-Franche-Comté',
#    'NUTS_NAME': 'Bourgogne-Franche-Comté',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRC'},
#   {'NUTS_ID': 'FRC2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Franche-Comté',
#    'NUTS_NAME': 'Franche-Comté',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRC2'},
#   {'NUTS_ID': 'FRC22',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Jura',
#    'NUTS_NAME': 'Jura',
#    'MOUNT_TYPE': 3,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRC22'}],
#  [{'NUTS_ID': 'FR',
#    'LEVL_CODE': 0,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'France',
#    'NUTS_NAME': 'France',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FR'},
#   {'NUTS_ID': 'FRK',
#    'LEVL_CODE': 1,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Auvergne-Rhône-Alpes',
#    'NUTS_NAME': 'Auvergne-Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK'},
#   {'NUTS_ID': 'FRK2',
#    'LEVL_CODE': 2,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Rhône-Alpes',
#    'NUTS_NAME': 'Rhône-Alpes',
#    'MOUNT_TYPE': 0,
#    'URBN_TYPE': None,
#    'COAST_TYPE': 0,
#    'FID': 'FRK2'},
#   {'NUTS_ID': 'FRK21',
#    'LEVL_CODE': 3,
#    'CNTR_CODE': 'FR',
#    'NAME_LATN': 'Ain',
#    'NUTS_NAME': 'Ain',
#    'MOUNT_TYPE': 4,
#    'URBN_TYPE': 3,
#    'COAST_TYPE': 3,
#    'FID': 'FRK21'}],
#  ...]

# %%
# store results in pandas df
df1 = pd.DataFrame(nuts, columns = ['country', 'NUTS1', 'NUTS2', 'NUTS3'])

# %%
df1
# Out:
#                                                 country  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2479  {'NUTS_ID': 'TR', 'LEVL_CODE': 0, 'CNTR_CODE':...
# 2480  {'NUTS_ID': 'TR', 'LEVL_CODE': 0, 'CNTR_CODE':...
# 2481  {'NUTS_ID': 'TR', 'LEVL_CODE': 0, 'CNTR_CODE':...
# 2482  {'NUTS_ID': 'TR', 'LEVL_CODE': 0, 'CNTR_CODE':...
# 2483  {'NUTS_ID': 'TR', 'LEVL_CODE': 0, 'CNTR_CODE':...
#
#                                                   NUTS1  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2479  {'NUTS_ID': 'TR4', 'LEVL_CODE': 1, 'CNTR_CODE'...
# 2480  {'NUTS_ID': 'TR3', 'LEVL_CODE': 1, 'CNTR_CODE'...
# 2481  {'NUTS_ID': 'TR3', 'LEVL_CODE': 1, 'CNTR_CODE'...
# 2482  {'NUTS_ID': 'TR3', 'LEVL_CODE': 1, 'CNTR_CODE'...
# 2483  {'NUTS_ID': 'TR6', 'LEVL_CODE': 1, 'CNTR_CODE'...
#
#                                                   NUTS2  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2479  {'NUTS_ID': 'TR41', 'LEVL_CODE': 2, 'CNTR_CODE...
# 2480  {'NUTS_ID': 'TR33', 'LEVL_CODE': 2, 'CNTR_CODE...
# 2481  {'NUTS_ID': 'TR33', 'LEVL_CODE': 2, 'CNTR_CODE...
# 2482  {'NUTS_ID': 'TR33', 'LEVL_CODE': 2, 'CNTR_CODE...
# 2483  {'NUTS_ID': 'TR61', 'LEVL_CODE': 2, 'CNTR_CODE...
#
#                                                   NUTS3
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2479  {'NUTS_ID': 'TR411', 'LEVL_CODE': 3, 'CNTR_COD...
# 2480  {'NUTS_ID': 'TR333', 'LEVL_CODE': 3, 'CNTR_COD...
# 2481  {'NUTS_ID': 'TR334', 'LEVL_CODE': 3, 'CNTR_COD...
# 2482  {'NUTS_ID': 'TR332', 'LEVL_CODE': 3, 'CNTR_COD...
# 2483  {'NUTS_ID': 'TR613', 'LEVL_CODE': 3, 'CNTR_COD...
#
# [2484 rows x 4 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  1168 non-null   object
#  1   NUTS1    1168 non-null   object
#  2   NUTS2    1168 non-null   object
#  3   NUTS3    1168 non-null   object
# dtypes: object(4)
# memory usage: 77.8+ KB

# %%
# extract substrings that include the relevant information on country and region from columns
df1['country'] = df1['country'].astype(str).str[13:15]
df1['NUTS1'] = df1['NUTS1'].astype(str).str[13:16]
df1['NUTS2'] = df1['NUTS2'].astype(str).str[13:17]
df1['NUTS3'] = df1['NUTS3'].astype(str).str[13:18]
df1
#13,14,15,16
# Out:
#      country NUTS1 NUTS2  NUTS3
# 0
# 1
# 2
# 3
# 4
# ...      ...   ...   ...    ...
# 2479      TR   TR4  TR41  TR411
# 2480      TR   TR3  TR33  TR333
# 2481      TR   TR3  TR33  TR334
# 2482      TR   TR3  TR33  TR332
# 2483      TR   TR6  TR61  TR613
#
# [2484 rows x 4 columns]

# %%
# reset indices of reverse geocoding df and previous weather df
df = df.reset_index()
df1 = df1.reset_index()
# concatenate both dfs
locations = pd.concat([df, df1], axis=1)
locations
# Out:
#          index  longitude  latitude                time       u10         d2m  \
# 0            0     -10.00     71.00 2018-05-01 02:00:00 -6.397677  274.760529
# 1         7344     -10.00     70.25 2018-05-01 02:00:00 -6.526506  275.174927
# 2        14688     -10.00     69.50 2018-05-01 02:00:00 -6.965965  275.057220
# 3        22032     -10.00     68.75 2018-05-01 02:00:00 -7.714090  274.774414
# 4        29376     -10.00     68.00 2018-05-01 02:00:00 -8.437366  274.559448
# ...        ...        ...       ...                 ...       ...         ...
# 2479  53625888      29.75     40.25 2018-05-01 02:00:00 -0.704992  282.959808
# 2480  53633232      29.75     39.50 2018-05-01 02:00:00 -0.580741  277.455475
# 2481  53640576      29.75     38.75 2018-05-01 02:00:00 -1.340637  273.789459
# 2482  53647920      29.75     38.00 2018-05-01 02:00:00 -0.574201  278.682373
# 2483  53655264      29.75     37.25 2018-05-01 02:00:00  0.495016  280.619598
#
#              t2m  uvb    lat    lon        lat_long  index country NUTS1  \
# 0     276.599854  0.0   71.0  -10.0   (71.0, -10.0)      0
# 1     277.215179  0.0  70.25  -10.0  (70.25, -10.0)      1
# 2     277.189667  0.0   69.5  -10.0   (69.5, -10.0)      2
# 3     276.953369  0.0  68.75  -10.0  (68.75, -10.0)      3
# 4     276.742554  0.0   68.0  -10.0   (68.0, -10.0)      4
# ...          ...  ...    ...    ...             ...    ...     ...   ...
# 2479  284.051086  0.0  40.25  29.75  (40.25, 29.75)   2479      TR   TR4
# 2480  284.869659  0.0   39.5  29.75   (39.5, 29.75)   2480      TR   TR3
# 2481  281.447937  0.0  38.75  29.75  (38.75, 29.75)   2481      TR   TR3
# 2482  288.373627  0.0   38.0  29.75   (38.0, 29.75)   2482      TR   TR3
# 2483  285.615448  0.0  37.25  29.75  (37.25, 29.75)   2483      TR   TR6
#
#      NUTS2  NUTS3
# 0
# 1
# 2
# 3
# 4
# ...    ...    ...
# 2479  TR41  TR411
# 2480  TR33  TR333
# 2481  TR33  TR334
# 2482  TR33  TR332
# 2483  TR61  TR613
#
# [2484 rows x 16 columns]

# %% [markdown]
# The unique locations now include the corresponding country and NUTS regions

# %%
# replace empty cells with NaN
locations = locations.replace(r'', np.nan, regex=True)
locations.head()
# Out:
#    index  longitude  latitude                time       u10         d2m  \
# 0      0      -10.0     71.00 2018-05-01 02:00:00 -6.397677  274.760529
# 1   7344      -10.0     70.25 2018-05-01 02:00:00 -6.526506  275.174927
# 2  14688      -10.0     69.50 2018-05-01 02:00:00 -6.965965  275.057220
# 3  22032      -10.0     68.75 2018-05-01 02:00:00 -7.714090  274.774414
# 4  29376      -10.0     68.00 2018-05-01 02:00:00 -8.437366  274.559448
#
#           t2m  uvb    lat    lon        lat_long  index country NUTS1 NUTS2  \
# 0  276.599854  0.0   71.0  -10.0   (71.0, -10.0)      0     NaN   NaN   NaN
# 1  277.215179  0.0  70.25  -10.0  (70.25, -10.0)      1     NaN   NaN   NaN
# 2  277.189667  0.0   69.5  -10.0   (69.5, -10.0)      2     NaN   NaN   NaN
# 3  276.953369  0.0  68.75  -10.0  (68.75, -10.0)      3     NaN   NaN   NaN
# 4  276.742554  0.0   68.0  -10.0   (68.0, -10.0)      4     NaN   NaN   NaN
#
#   NUTS3
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
# drop observations that do not have information on country (likely locations on the sea)
locations = locations[locations['country'].notna()]
locations.head()
# Out:
#       index  longitude  latitude                time       u10         d2m  \
# 25   183600     -10.00     52.25 2018-05-01 02:00:00  1.419710  276.346252
# 69  1175040      -9.25     53.75 2018-05-01 02:00:00  0.718015  276.432098
# 70  1182384      -9.25     53.00 2018-05-01 02:00:00  0.432891  276.576782
# 71  1189728      -9.25     52.25 2018-05-01 02:00:00  0.773602  275.237061
# 89  1321920      -9.25     38.75 2018-05-01 02:00:00  1.162051  281.014404
#
#            t2m  uvb    lat    lon        lat_long  index country NUTS1 NUTS2  \
# 25  280.795715  0.0  52.25  -10.0  (52.25, -10.0)     25      IE   IE0  IE05
# 69  279.697357  0.0  53.75  -9.25  (53.75, -9.25)     69      IE   IE0  IE04
# 70  280.215363  0.0   53.0  -9.25   (53.0, -9.25)     70      IE   IE0  IE05
# 71  278.616028  0.0  52.25  -9.25  (52.25, -9.25)     71      IE   IE0  IE05
# 89  284.209900  0.0  38.75  -9.25  (38.75, -9.25)     89      PT   PT1  PT17
#
#     NUTS3
# 25  IE053
# 69  IE042
# 70  IE051
# 71  IE053
# 89  PT170

# %%
locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 25 to 2483
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      1168 non-null   int64
#  1   longitude  1168 non-null   float64
#  2   latitude   1168 non-null   float64
#  3   time       1168 non-null   datetime64[ns]
#  4   u10        1168 non-null   float32
#  5   d2m        1168 non-null   float32
#  6   t2m        1168 non-null   float32
#  7   uvb        1168 non-null   float32
#  8   lat        1168 non-null   object
#  9   lon        1168 non-null   object
#  10  lat_long   1168 non-null   object
#  11  index      1168 non-null   int64
#  12  country    1168 non-null   object
#  13  NUTS1      1168 non-null   object
#  14  NUTS2      1168 non-null   object
#  15  NUTS3      1168 non-null   object
# dtypes: datetime64[ns](1), float32(4), float64(2), int64(2), object(7)
# memory usage: 136.9+ KB

# %%
# show unique countries
locations['country'].unique()
# Out:
# array(['IE', 'PT', 'ES', 'UK', 'FR', 'NL', 'BE', 'NO', 'DE', 'CH', 'IT',
#        'DK', 'AT', 'SE', 'CZ', 'SI', 'HR', 'PL', 'SK', 'HU', 'ME', 'RS',
#        'AL', 'MK', 'EL', 'FI', 'LV', 'LT', 'RO', 'EE', 'BG', 'TR'],
#       dtype=object)

# %%
# keep only relevant variables that are needed to be merged
locations = locations[['lat','lon', 'country', 'NUTS1', 'NUTS2', 'NUTS3']]
locations.head()
# Out:
#       lat    lon country NUTS1 NUTS2  NUTS3
# 25  52.25  -10.0      IE   IE0  IE05  IE053
# 69  53.75  -9.25      IE   IE0  IE04  IE042
# 70   53.0  -9.25      IE   IE0  IE05  IE051
# 71  52.25  -9.25      IE   IE0  IE05  IE053
# 89  38.75  -9.25      PT   PT1  PT17  PT170

# %%
# drop locations from countries that do not provide mortality data or are located outside of Europe
non_european = ['SJ', 'GB', 'IM', 'JE', 'DZ', 'TN', 'BA', 'RU', 'XK', 'MK', 'UA', 'BY', 'TR', 'MD']
locations = locations[~locations['country'].isin(non_european)]
locations.shape
# Out:
# (1156, 6)

# %%
# write data to csv
locations.to_csv('locations1.csv')
