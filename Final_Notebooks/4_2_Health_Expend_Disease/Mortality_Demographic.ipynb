# %% [markdown]
# # Loading mortality and demographic data from Eurostat

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading and setting up mortality data

# %%
# load raw data on mortality from Eurostat
mortality = pd.read_csv('demo_r_mwk2_ts_1_Data.csv', sep=',', encoding='latin-1')
# missing values to -1
mortality = mortality.replace(':','-1')
mortality = mortality.replace('inf','-2')
# remove comma from figures
mortality['Value'] = mortality['Value'].str.replace(',','')
# drop unnecessary columns
mortality = mortality.drop(['UNIT', 'Flag and Footnotes', 'SEX'], axis=1)
# extract country code week number and year
mortality['country'] = mortality['GEO'].astype(str).str[0:2]
mortality['week_nr'] = mortality['TIME'].astype(str).str[4:7]
mortality['year'] = mortality['TIME'].astype(str).str[0:4]
# rename column to deatgs
mortality = mortality.rename(columns={'Value': 'deaths'})
# converting deaths to integer
mortality['deaths'] = mortality['deaths'].astype(int)
# set missing values previously set to -1 to Nan
mortality['deaths'] = np.where(mortality['deaths'] < 0, np.NaN, mortality['deaths'])
mortality.head()
# Out:
#       TIME   GEO                                          GEO_LABEL  deaths  \
# 0  2000W01    BE                                            Belgium  2814.0
# 1  2000W01   BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   298.0
# 2  2000W01  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...   298.0
# 3  2000W01   BE2                                      Vlaams Gewest  1443.0
# 4  2000W01  BE21                                    Prov. Antwerpen   439.0
#
#   country week_nr  year
# 0      BE     W01  2000
# 1      BE     W01  2000
# 2      BE     W01  2000
# 3      BE     W01  2000
# 4      BE     W01  2000

# %%
deaths = pd.DataFrame(mortality['deaths'])
deaths.head()
# Out:
#    deaths
# 0  2814.0
# 1   298.0
# 2   298.0
# 3  1443.0
# 4   439.0

# %%
deaths[~deaths.applymap(np.isreal).all(1)]
# Out:
# Empty DataFrame
# Columns: [deaths]
# Index: []

# %%
mortality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484992 entries, 0 to 484991
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   TIME       484992 non-null  object
#  1   GEO        484992 non-null  object
#  2   GEO_LABEL  484992 non-null  object
#  3   deaths     335330 non-null  float64
#  4   country    484992 non-null  object
#  5   week_nr    484992 non-null  object
#  6   year       484992 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 25.9+ MB

# %%
mortality.shape
# Out:
# (484992, 7)

# %%
# load mortality on Nuts 3 for exceptionally large NUTS2 regions: https://ec.europa.eu/eurostat/databrowser/view/DEMO_R_MWK3_T__custom_2768883/default/table?lang=en
mortality_NUTS3 = pd.read_csv('demo_r_mweek3_1_Data.csv', sep=',', encoding='latin-1')
# missing values to -1
mortality_NUTS3 = mortality_NUTS3.replace(':','-1')
mortality_NUTS3 = mortality_NUTS3.replace('inf','-2')
# remove comma from figures
mortality_NUTS3['Value'] = mortality_NUTS3['Value'].str.replace(',','')
# drop unnecessary columns
mortality_NUTS3 = mortality_NUTS3.drop(['UNIT', 'SEX', 'AGE'], axis=1)
# extract country code week number and year
mortality_NUTS3['country'] = mortality_NUTS3['GEO'].astype(str).str[0:2]
mortality_NUTS3['week_nr'] = mortality_NUTS3['TIME'].astype(str).str[4:7]
mortality_NUTS3['year'] = mortality_NUTS3['TIME'].astype(str).str[0:4]
# rename column to deatgs
mortality_NUTS3 = mortality_NUTS3.rename(columns={'Value': 'deaths'})
# converting deaths to integer
mortality_NUTS3['deaths'] = mortality_NUTS3['deaths'].astype(float)
# set missing values previously set to -1 to Nan
mortality_NUTS3['deaths'] = np.where(mortality_NUTS3['deaths'] < 0, np.NaN, mortality_NUTS3['deaths'])
mortality_NUTS3.head()
mortality_NUTS3.head()
# Out:
#       TIME    GEO  deaths country week_nr  year
# 0  2000W01  FI1D1    46.0      FI     W01  2000
# 1  2000W01  FI1D2    66.0      FI     W01  2000
# 2  2000W01  FI1D3    45.0      FI     W01  2000
# 3  2000W01  FI1D5    14.0      FI     W01  2000
# 4  2000W01  FI1D7    44.0      FI     W01  2000

# %%
# concatenate overall mortality with NUTS3 mortality
frames = [mortality,mortality_NUTS3]
mortality = pd.concat(frames)

# %% [markdown]
# ## loading and setting up population figure

# %% [markdown]
# ### population density

# %%
# read density data from Eurostat
density = pd.read_csv('demo_r_d3dens_1_Data.csv', sep=',', encoding='latin-1')
# missing values to -1
density = density.replace(':','-1')
# remove comma from figures
density['Value'] = density['Value'].str.replace(',','')
# rename columns
density = density.rename(columns={'TIME': 'year', 'Value': 'density'})
# convert density to integer
density['year'] = density['year'].astype(str)
density['density'] = density['density'].astype(float)
# set missing values previously set to -1 to Nan
density['density'] = np.where(density['density'] <= 0, np.NaN, density['density'])
density = density.drop(['UNIT'],1)
density.head(3)
# Out:
#    year        GEO  density
# 0  2000  EU27_2020    104.2
# 1  2000       EU28    111.9
# 2  2000  EU27_2007    112.3

# %% [markdown]
# No data for 2020 and 2021. Hence, data for 2020 and 2021 will be added to the 'density' dataframe. This is done by subsetting the data for 2019 and setting the year to 2020 and 2021, and then concatenating the subset for 2020 with the original dataframe. That way data for the year 2021 is included in the data with the population figures of 2020.

# %%
# use values of 2019 for 2020 and 2021
dens_2020 = density[density['year'] == '2019']
dens_2020['year'] = '2020'
dens_2021 = density[density['year'] == '2019']
dens_2021['year'] = '2021'
dens_2020.head()
# Out:
# <ipython-input-10-5485371700d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dens_2020['year'] = '2020'
# <ipython-input-10-5485371700d3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dens_2021['year'] = '2021'
#        year        GEO  density
# 38418  2020  EU27_2020    109.0
# 38419  2020       EU28      NaN
# 38420  2020  EU27_2007      NaN
# 38421  2020         BE    377.3
# 38422  2020        BE1   7526.7

# %%
# concatenate all frames
frames = [density, dens_2020,dens_2021]
density = pd.concat(frames)
density
# Out:
#        year        GEO  density
# 0      2000  EU27_2020    104.2
# 1      2000       EU28    111.9
# 2      2000  EU27_2007    112.3
# 3      2000         BE    338.0
# 4      2000        BE1   5974.3
# ...     ...        ...      ...
# 40435  2021       TRC3     89.2
# 40436  2021      TRC31     95.9
# 40437  2021      TRC32    131.1
# 40438  2021      TRC33     75.5
# 40439  2021      TRC34     60.7
#
# [44484 rows x 3 columns]

# %%
# inspect code length as indicator of NUTS regions in the data
density['code_length'] = density.GEO.str.len()
density['code_length'].value_counts()
# Out:
# 5    33528
# 4     7348
# 3     2750
# 2      814
# 9       44
# Name: code_length, dtype: int64

# %%
# load raw population data
population = pd.read_csv('demo_r_d2jan_1_Data.csv', sep=',', encoding='latin-1')
# missing values to -1
population = population.replace(':','-1')
# remove comma from figures
population['Value'] = population['Value'].str.replace(',','')
# rename columns
population = population.rename(columns={'TIME': 'year', 'Value': 'population'})
# convert population to integer
population['year'] = population['year'].astype(str)
population['population'] = population['population'].astype(int)
# set missing values previously set to -1 to Nan
population['population'] = np.where(population['population'] <= 0, np.NaN, population['population'])
population.head(3)
# Out:
#    year        GEO                                  GEO_LABEL    SEX    AGE  \
# 0  2000  EU27_2020  European Union - 27 countries (from 2020)  Total  Total
# 1  2000       EU28  European Union - 28 countries (2013-2020)  Total  Total
# 2  2000  EU27_2007  European Union - 27 countries (2007-2013)  Total  Total
#
#      UNIT   population
# 0  Number  428473834.0
# 1  Number  487259080.0
# 2  Number  482761345.0

# %%
# download for NUTS 3 regions (https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=demo_r_pjanaggr3&lang=en)
population_NUTS3 = pd.read_csv('demo_r_pjanaggr3_1_Data.csv', sep=',', encoding='latin-1')
# missing values to -1
population_NUTS3 = population_NUTS3.replace(':','-1')
# remove comma from figures
population_NUTS3['Value'] = population_NUTS3['Value'].str.replace(',','')
# rename columns
population_NUTS3 = population_NUTS3.rename(columns={'TIME': 'year', 'Value': 'population'})
# convert population to integer
population_NUTS3['year'] = population_NUTS3['year'].astype(str)
population_NUTS3['population'] = population_NUTS3['population'].astype(int)
# set missing values previously set to -1 to Nan
population_NUTS3['population'] = np.where(population_NUTS3['population'] <= 0, np.NaN, population_NUTS3['population'])
population_NUTS3.head(3)
# Out:
#    year    GEO    SEX    AGE    UNIT  population
# 0  2000  FI1D1  Total  Total  Number    167958.0
# 1  2000  FI1D2  Total  Total  Number    255456.0
# 2  2000  FI1D3  Total  Total  Number    172551.0

# %%
population.shape
# Out:
# (10647, 7)

# %%
# concatenate overall and NUTS3 population
frames = [population, population_NUTS3]
population = pd.concat(frames)
population.shape
# Out:
# (11043, 7)

# %%
# get value counts for year
population['year'].value_counts()
# Out:
# 2000    525
# 2003    525
# 2005    525
# 2019    525
# 2002    525
# 2020    525
# 2009    525
# 2004    525
# 2016    525
# 2013    525
# 2010    525
# 2001    525
# 2014    525
# 2012    525
# 2006    525
# 2011    525
# 2007    525
# 2017    525
# 2018    525
# 2008    525
# 2015    525
# 2021     18
# Name: year, dtype: int64

# %% [markdown]
# No data for  2021. Hence, data for 2021 will be added to the 'population' dataframe. This is done by subsetting the data for 2019 and setting the year to 2021, and then concatenating the subset for 2020 with the original dataframe. That way data for the year 2021 is included in the data with the population figures of 2020.

# %%
# use figures of 2020 for 2021
pop_2020 = population[population['year'] == '2020']
pop_2020['year'] = '2021'
pop_2020.head()
# Out:
# <ipython-input-19-83adbca57ec7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_2020['year'] = '2021'
#        year        GEO                                          GEO_LABEL  \
# 10140  2021  EU27_2020          European Union - 27 countries (from 2020)
# 10141  2021       EU28          European Union - 28 countries (2013-2020)
# 10142  2021  EU27_2007          European Union - 27 countries (2007-2013)
# 10143  2021         BE                                            Belgium
# 10144  2021        BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...
#
#          SEX    AGE    UNIT   population
# 10140  Total  Total  Number  447319916.0
# 10141  Total  Total  Number          NaN
# 10142  Total  Total  Number          NaN
# 10143  Total  Total  Number   11522440.0
# 10144  Total  Total  Number    1223364.0

# %%
# get shape
pop_2020.shape
# Out:
# (525, 7)

# %%
# concatenate all frames
frames = [population, pop_2020]
population = pd.concat(frames)
population['year'].value_counts()
# Out:
# 2021    543
# 2000    525
# 2010    525
# 2005    525
# 2019    525
# 2002    525
# 2020    525
# 2009    525
# 2004    525
# 2016    525
# 2013    525
# 2001    525
# 2003    525
# 2014    525
# 2012    525
# 2006    525
# 2011    525
# 2007    525
# 2017    525
# 2018    525
# 2008    525
# 2015    525
# Name: year, dtype: int64

# %%
# merge population and density figures
population = population.merge(density, on=['year', 'GEO'])
population
# Out:
#        year        GEO                                          GEO_LABEL  \
# 0      2000  EU27_2020          European Union - 27 countries (from 2020)
# 1      2000       EU28          European Union - 28 countries (2013-2020)
# 2      2000  EU27_2007          European Union - 27 countries (2007-2013)
# 3      2000         BE                                            Belgium
# 4      2000        BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...
# ...     ...        ...                                                ...
# 11342  2021       TRB2                          Van, Mus, Bitlis, Hakkari
# 11343  2021        TRC                                  Güneydogu Anadolu
# 11344  2021       TRC1                         Gaziantep, Adiyaman, Kilis
# 11345  2021       TRC2                              Sanliurfa, Diyarbakir
# 11346  2021       TRC3                      Mardin, Batman, Sirnak, Siirt
#
#          SEX    AGE    UNIT   population  density  code_length
# 0      Total  Total  Number  428473834.0    104.2            9
# 1      Total  Total  Number  487259080.0    111.9            4
# 2      Total  Total  Number  482761345.0    112.3            9
# 3      Total  Total  Number   10239085.0    338.0            2
# 4      Total  Total  Number     959318.0   5974.3            3
# ...      ...    ...     ...          ...      ...          ...
# 11342  Total  Total  Number    2174672.0     53.7            4
# 11343  Total  Total  Number    8975618.0    119.1            3
# 11344  Total  Total  Number    2838319.0    185.7            4
# 11345  Total  Total  Number    3829967.0    111.9            4
# 11346  Total  Total  Number    2307332.0     89.2            4
#
# [11347 rows x 9 columns]

# %%
# value count of code lebgth
population['code_length'] = population.GEO.str.len()
population['code_length'].value_counts()
# Out:
# 4    7348
# 3    2750
# 2     814
# 5     391
# 9      44
# Name: code_length, dtype: int64

# %% [markdown]
# The new dataframe consists data from 2020 and 2021.

# %%
# get shape
population.shape
# Out:
# (11347, 9)

# %%
# transform variables to numeric
population['population'] = pd.to_numeric(population['population'], errors='coerce')
population['year'] = pd.to_numeric(population['year'], errors='coerce')

# %%
# exclude non-EU countries, unknown regions and oversees regions
non_EU = ['UK', 'TR']
non_EU_GEO = ['MKX', 'FRY', 'FRX', 'HUX']
# get country code
population['country'] = population['GEO'].str[:2]
population = population[~population['country'].isin(non_EU)]
# remove French oversees departments and other redundant regions
population = population[~population['GEO'].isin(non_EU_GEO)]
population.head()
# Out:
#    year        GEO                                          GEO_LABEL    SEX  \
# 0  2000  EU27_2020          European Union - 27 countries (from 2020)  Total
# 1  2000       EU28          European Union - 28 countries (2013-2020)  Total
# 2  2000  EU27_2007          European Union - 27 countries (2007-2013)  Total
# 3  2000         BE                                            Belgium  Total
# 4  2000        BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
#
#      AGE    UNIT   population  density  code_length country
# 0  Total  Number  428473834.0    104.2            9      EU
# 1  Total  Number  487259080.0    111.9            4      EU
# 2  Total  Number  482761345.0    112.3            9      EU
# 3  Total  Number   10239085.0    338.0            2      BE
# 4  Total  Number     959318.0   5974.3            3      BE

# %% [markdown]
# ## Checking for size of NUTS1 regions in weather data

# %% [markdown]
# #weather_final = pd.read_csv('Heat_wave.csv')
# #weather_final['NUTS1'].value_counts().head(10)

# %%
#weather_final = pd.read_csv('Heat_wave.csv')
#weather_final['NUTS2'].value_counts().head(10)

# %% [markdown]
# ### For the Netherlands, mortality data is only available on the national level for a long time period. Therefore, the Netherlands will be kept in the data as a whole nation instead of NUTS 1 regions.

# %%
mortality_NUTS3['GEO'].unique()
# Out:
# array(['FI1D1', 'FI1D2', 'FI1D3', 'FI1D5', 'FI1D7', 'FI1D8', 'FI1D9',
#        'SE311', 'SE312', 'SE313', 'SE321', 'SE322', 'SE331', 'SE332',
#        'NO071', 'NO072', 'NO073', 'NO074'], dtype=object)

# %% [markdown]
# ## Keeping only NUTS1 and NUTS 2 regions except for the Netherlands (NL), mainland Finland (FI1), Norway (NO0), Northern Sweden (SE3). For these regions NUTS3 regions will be used

# %%
regions = ['FI1D1', 'FI1D2', 'FI1D3', 'FI1D5', 'FI1D7', 'FI1D8', 'FI1D9','SE311', 'SE312', 'SE313', 'SE321', 'SE322',
           'SE331', 'SE332','NO071', 'NO072', 'NO073', 'NO074', 'NL']
regions
# Out:
# ['FI1D1',
#  'FI1D2',
#  'FI1D3',
#  'FI1D5',
#  'FI1D7',
#  'FI1D8',
#  'FI1D9',
#  'SE311',
#  'SE312',
#  'SE313',
#  'SE321',
#  'SE322',
#  'SE331',
#  'SE332',
#  'NO071',
#  'NO072',
#  'NO073',
#  'NO074',
#  'NL']

# %%
# filter NUTS 1, NUTS 2 mortality OR in one of the specified special regions
population['code_length'] = population.GEO.str.len()
# keep only NUTS1 regions
population = population[(population['code_length'] == 4) | (population['code_length'] == 3) | (population['GEO'].isin(regions))]
population.head()
# Out:
#    year   GEO                                          GEO_LABEL    SEX  \
# 1  2000  EU28          European Union - 28 countries (2013-2020)  Total
# 4  2000   BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
# 5  2000  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
# 6  2000   BE2                                      Vlaams Gewest  Total
# 7  2000  BE21                                    Prov. Antwerpen  Total
#
#      AGE    UNIT   population  density  code_length country
# 1  Total  Number  487259080.0    111.9            4      EU
# 4  Total  Number     959318.0   5974.3            3      BE
# 5  Total  Number     959318.0   5974.3            4      BE
# 6  Total  Number    5940251.0    445.0            3      BE
# 7  Total  Number    1643972.0    589.1            4      BE

# %%
# check value counts
population['code_length'].value_counts()
# Out:
# 4    5874
# 3    2200
# 5     391
# 2      22
# Name: code_length, dtype: int64

# %% [markdown]
# ### checking for missing values

# %%
# filter missing values
filtered_df = population[population['population'].isnull()]
filtered_df.head(5)
# Out:
#        year    GEO                                  GEO_LABEL    SEX    AGE  \
# 39     2000   DK01                                Hovedstaden  Total  Total
# 40     2000   DK02                                   Sjælland  Total  Total
# 41     2000   DK03                                 Syddanmark  Total  Total
# 42     2000   DK04                                Midtjylland  Total  Total
# 43     2000   DK05                                Nordjylland  Total  Total
# ...     ...    ...                                        ...    ...    ...
# 10541  2004  NO072                                        NaN  Total  Total
# 10542  2004  NO073                                        NaN  Total  Total
# 10845  2021  NO072                                        NaN  Total  Total
# 10847  2021  NO073                                        NaN  Total  Total
# 10850  2021   EU28  European Union - 28 countries (2013-2020)  Total  Total
#
#          UNIT  population  density  code_length country
# 39     Number         NaN      NaN            4      DK
# 40     Number         NaN      NaN            4      DK
# 41     Number         NaN      NaN            4      DK
# 42     Number         NaN      NaN            4      DK
# 43     Number         NaN      NaN            4      DK
# ...       ...         ...      ...          ...     ...
# 10541  Number         NaN      6.1            5      NO
# 10542  Number         NaN      1.6            5      NO
# 10845  Number         NaN      6.6            5      NO
# 10847  Number         NaN      1.6            5      NO
# 10850  Number         NaN      NaN            4      EU
#
# [456 rows x 10 columns]

# %%
# sort by NUTS region and year and replace missing values with the previous row
population = population.sort_values(by=['GEO', 'year'])
population['population'] = population['population'].fillna(method='bfill')
population['density'] = population['density'].fillna(method='bfill')

# %%
# all missing values for region PL84 have been removed for instance
population[population['GEO'] == 'PL84']
# Out:
#        year   GEO  GEO_LABEL    SEX    AGE    UNIT  population  density  \
# 304    2000  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 802    2001  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 1300   2002  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 1798   2003  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 2296   2004  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 2794   2005  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 3292   2006  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 3790   2007  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 4288   2008  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 4786   2009  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 5284   2010  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 5782   2011  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 6280   2012  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 6778   2013  PL84  Podlaskie  Total  Total  Number   1165447.0     58.6
# 7276   2014  PL84  Podlaskie  Total  Total  Number   1165447.0     58.2
# 7774   2015  PL84  Podlaskie  Total  Total  Number   1162369.0     58.0
# 8272   2016  PL84  Podlaskie  Total  Total  Number   1158945.0     57.9
# 8770   2017  PL84  Podlaskie  Total  Total  Number   1156947.0     57.8
# 9268   2018  PL84  Podlaskie  Total  Total  Number   1154856.0     57.7
# 9766   2019  PL84  Podlaskie  Total  Total  Number   1152074.0     57.5
# 10264  2020  PL84  Podlaskie  Total  Total  Number   1149389.0     57.5
# 11153  2021  PL84  Podlaskie  Total  Total  Number   1149389.0     57.5
#
#        code_length country
# 304              4      PL
# 802              4      PL
# 1300             4      PL
# 1798             4      PL
# 2296             4      PL
# 2794             4      PL
# 3292             4      PL
# 3790             4      PL
# 4288             4      PL
# 4786             4      PL
# 5284             4      PL
# 5782             4      PL
# 6280             4      PL
# 6778             4      PL
# 7276             4      PL
# 7774             4      PL
# 8272             4      PL
# 8770             4      PL
# 9268             4      PL
# 9766             4      PL
# 10264            4      PL
# 11153            4      PL

# %%
# now missing values left
filtered_df1 = population[population['population'].isnull()]
filtered_df1
# Out:
# Empty DataFrame
# Columns: [year, GEO, GEO_LABEL, SEX, AGE, UNIT, population, density, code_length, country]
# Index: []

# %% [markdown]
# ## loading data on population over 65

# %%
# loading data separately for different age groups that will be added to obtain the population number of 65 or older
age65_69 = pd.read_csv('demo_r_pjangroup_1_Data_65_69.csv', sep=',', encoding='latin-1')
age70_74 = pd.read_csv('demo_r_pjangroup_1_Data_70_74.csv', sep=',', encoding='latin-1')
over_74 = pd.read_csv('demo_r_pjangroup_1_Data_75+.csv', sep=',', encoding='latin-1')

# rename column
age65_69 = age65_69.rename(columns={'Value': 'age_65_69'})
# set missing values to NaN
age65_69 = age65_69.replace(':','-1')
age65_69['age_65_69'] = np.where(age65_69['age_65_69'] == '-1', np.NaN, age65_69['age_65_69'])

# rename column
age70_74 = age70_74.rename(columns={'Value': 'age_70_74'})
# keep only relevant columns to facilitate the merging
age70_74 = age70_74[['TIME', 'GEO', 'age_70_74']]
# set missing values to NaN
age70_74 = age70_74.replace(':','-1')
age70_74['age_70_74'] = np.where(age70_74['age_70_74'] == '-1', np.NaN, age70_74['age_70_74'])

# rename column
over_74 = over_74.rename(columns={'Value': 'age_over_74'})
# keep only relevant columns to facilitate the merging
over_74 = over_74[['TIME', 'GEO', 'age_over_74']]
# set missing values to NaN
over_74 = over_74.replace(':','-1')
over_74['age_over_74'] = np.where(over_74['age_over_74'] == '-1', np.NaN, over_74['age_over_74'])

# %%
# merge data into one dataframe
final_age = age65_69.merge(age70_74, how='inner', on=['GEO','TIME'])
final_age = final_age.merge(over_74, how='inner', on=['GEO','TIME'])
final_age.head()
# Out:
#    TIME   GEO                                          GEO_LABEL    SEX  \
# 0  2000    BE                                            Belgium  Total
# 1  2000   BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
# 2  2000  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
# 3  2000   BE2                                      Vlaams Gewest  Total
# 4  2000  BE21                                    Prov. Antwerpen  Total
#
#       AGE    UNIT age_65_69 age_70_74 age_over_74
# 0  Y65-69  Number   521,416   457,815     735,862
# 1  Y65-69  Number    42,109    39,907      78,892
# 2  Y65-69  Number    42,109    39,907      78,892
# 3  Y65-69  Number   313,903   264,867     415,046
# 4  Y65-69  Number    85,669    73,830     118,415

# %%
final_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10563 entries, 0 to 10562
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TIME         10563 non-null  int64
#  1   GEO          10563 non-null  object
#  2   GEO_LABEL    10563 non-null  object
#  3   SEX          10563 non-null  object
#  4   AGE          10563 non-null  object
#  5   UNIT         10563 non-null  object
#  6   age_65_69    9562 non-null   object
#  7   age_70_74    9562 non-null   object
#  8   age_over_74  9537 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 825.2+ KB

# %%
# remove comma from figures and convert to numeric
final_age['age_65_69'] = final_age['age_65_69'].str.replace(',','')
final_age['age_65_69'] = pd.to_numeric(final_age['age_65_69'], errors='coerce')

# remove comma from figures and convert to numeric
final_age['age_70_74'] = final_age['age_70_74'].str.replace(',','')
final_age['age_70_74'] = pd.to_numeric(final_age['age_70_74'], errors='coerce')

# remove comma from figures and convert to numeric
final_age['age_over_74'] = final_age['age_over_74'].str.replace(',','')
final_age['age_over_74'] = pd.to_numeric(final_age['age_over_74'], errors='coerce')

# add up the numbers to obtain the population of 65 years or older
final_age['population_65+'] = final_age['age_65_69'] + final_age['age_70_74'] + final_age['age_over_74']
final_age
# Out:
#        TIME   GEO                                          GEO_LABEL    SEX  \
# 0      2000    BE                                            Belgium  Total
# 1      2000   BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
# 2      2000  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...  Total
# 3      2000   BE2                                      Vlaams Gewest  Total
# 4      2000  BE21                                    Prov. Antwerpen  Total
# ...     ...   ...                                                ...    ...
# 10558  2020  TRB2                          Van, Mus, Bitlis, Hakkari  Total
# 10559  2020   TRC                                  Güneydogu Anadolu  Total
# 10560  2020  TRC1                         Gaziantep, Adiyaman, Kilis  Total
# 10561  2020  TRC2                              Sanliurfa, Diyarbakir  Total
# 10562  2020  TRC3                      Mardin, Batman, Sirnak, Siirt  Total
#
#           AGE    UNIT  age_65_69  age_70_74  age_over_74  population_65+
# 0      Y65-69  Number   521416.0   457815.0     735862.0       1715093.0
# 1      Y65-69  Number    42109.0    39907.0      78892.0        160908.0
# 2      Y65-69  Number    42109.0    39907.0      78892.0        160908.0
# 3      Y65-69  Number   313903.0   264867.0     415046.0        993816.0
# 4      Y65-69  Number    85669.0    73830.0     118415.0        277914.0
# ...       ...     ...        ...        ...          ...             ...
# 10558  Y65-69  Number    35236.0    25679.0      33085.0         94000.0
# 10559  Y65-69  Number   158526.0   120257.0     170472.0        449255.0
# 10560  Y65-69  Number    63033.0    47843.0      63399.0        174275.0
# 10561  Y65-69  Number    59965.0    44552.0      63080.0        167597.0
# 10562  Y65-69  Number    35528.0    27862.0      43993.0        107383.0
#
# [10563 rows x 10 columns]

# %%
# download for NUTS 3 regions (https://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=demo_r_pjanaggr3&lang=en)
population65_NUTS3 = pd.read_csv('demo_r_pjanaggr3_1_Data_65.csv', sep=',', encoding='latin-1')
# missing values to -1
population65_NUTS3 = population65_NUTS3.replace(':','-1')
# remove comma from figures
population65_NUTS3['Value'] = population65_NUTS3['Value'].str.replace(',','')
# rename columns
population65_NUTS3 = population65_NUTS3.rename(columns={'Value': 'population_65+'})
# convert population to integer
population65_NUTS3['TIME'] = population65_NUTS3['TIME'].astype(str)
population65_NUTS3['population_65+'] = population65_NUTS3['population_65+'].astype(int)
# set missing values previously set to -1 to Nan
population65_NUTS3['population_65+'] = np.where(population65_NUTS3['population_65+'] <= 0, np.NaN, population65_NUTS3['population_65+'])
population65_NUTS3.head(3)
# Out:
#    TIME    GEO    SEX               AGE    UNIT  population_65+
# 0  2000  FI1D1  Total  65 years or over  Number         31344.0
# 1  2000  FI1D2  Total  65 years or over  Number         41986.0
# 2  2000  FI1D3  Total  65 years or over  Number         28613.0

# %%
final_age.shape
# Out:
# (10563, 10)

# %%
# drop not needed variables
final_age = final_age.drop(['GEO_LABEL', 'age_65_69', 'age_70_74', 'age_over_74'],1)
frames = [final_age,population65_NUTS3]
final_age = pd.concat(frames)
#final_age = final_age.reset_index()
final_age.shape
# Out:
# (10959, 6)

# %%
final_age.head()
# Out:
#    TIME   GEO    SEX     AGE    UNIT  population_65+
# 0  2000    BE  Total  Y65-69  Number       1715093.0
# 1  2000   BE1  Total  Y65-69  Number        160908.0
# 2  2000  BE10  Total  Y65-69  Number        160908.0
# 3  2000   BE2  Total  Y65-69  Number        993816.0
# 4  2000  BE21  Total  Y65-69  Number        277914.0

# %%
# exclude non-EU countries
non_EU = ['UK', 'TR']
non_EU_GEO = ['MKX', 'FRY', 'FRX', 'HUX']
# get country code
final_age['country'] = final_age['GEO'].str[:2]
final_age = final_age[~final_age['country'].isin(non_EU)]
# remove French oversees departments and other redundant regions
final_age = final_age[~final_age['GEO'].isin(non_EU_GEO)]
final_age.head()
# Out:
#    TIME   GEO    SEX     AGE    UNIT  population_65+ country
# 0  2000    BE  Total  Y65-69  Number       1715093.0      BE
# 1  2000   BE1  Total  Y65-69  Number        160908.0      BE
# 2  2000  BE10  Total  Y65-69  Number        160908.0      BE
# 3  2000   BE2  Total  Y65-69  Number        993816.0      BE
# 4  2000  BE21  Total  Y65-69  Number        277914.0      BE

# %%
# filter NUTS 1, NUTS 2 mortality OR in one of the specified special regions
final_age['code_length'] = final_age.GEO.str.len()
# keep only NUTS1 regions
final_age = final_age[(final_age['code_length'] == 4) | (final_age['code_length'] == 3) | (final_age['GEO'].isin(regions))]
final_age.head()
# Out:
#    TIME   GEO    SEX     AGE    UNIT  population_65+ country  code_length
# 1  2000   BE1  Total  Y65-69  Number        160908.0      BE            3
# 2  2000  BE10  Total  Y65-69  Number        160908.0      BE            4
# 3  2000   BE2  Total  Y65-69  Number        993816.0      BE            3
# 4  2000  BE21  Total  Y65-69  Number        277914.0      BE            4
# 5  2000  BE22  Total  Y65-69  Number        109464.0      BE            4

# %% [markdown]
# ### checking for missing values

# %%
# check missing data
filtered_df = final_age[final_age['population_65+'].isnull()]
filtered_df.head()
# Out:
#      TIME    GEO    SEX               AGE    UNIT  population_65+ country  \
# 36   2000   DK01  Total            Y65-69  Number             NaN      DK
# 37   2000   DK02  Total            Y65-69  Number             NaN      DK
# 38   2000   DK03  Total            Y65-69  Number             NaN      DK
# 39   2000   DK04  Total            Y65-69  Number             NaN      DK
# 40   2000   DK05  Total            Y65-69  Number             NaN      DK
# ..    ...    ...    ...               ...     ...             ...     ...
# 341  2018  NO074  Total  65 years or over  Number             NaN      NO
# 359  2019  NO074  Total  65 years or over  Number             NaN      NO
# 377  2020  NO074  Total  65 years or over  Number             NaN      NO
# 393  2021  NO072  Total  65 years or over  Number             NaN      NO
# 394  2021  NO073  Total  65 years or over  Number             NaN      NO
#
#      code_length
# 36             4
# 37             4
# 38             4
# 39             4
# 40             4
# ..           ...
# 341            5
# 359            5
# 377            5
# 393            5
# 394            5
#
# [578 rows x 8 columns]

# %%
# NaN removed with values of following year in same NUTS region
final_age = final_age.sort_values(by=['GEO', 'TIME'])
final_age['population_65+'] = final_age['population_65+'].fillna(method='bfill')

# %%
# all missing values have been imputed
filtered_df = final_age[final_age['population_65+'].isnull()]
filtered_df
# Out:
# Empty DataFrame
# Columns: [TIME, GEO, SEX, AGE, UNIT, population_65+, country, code_length]
# Index: []

# %%
# deleting redundant columns
final_age = final_age.drop(['SEX', 'AGE', 'UNIT', 'code_length'], axis=1)
final_age = final_age.rename(columns={'TIME': 'year'})
final_age.head()
# Out:
#       year  GEO  population_65+ country
# 451   2000  AL0        237042.0      AL
# 954   2001  AL0        237042.0      AL
# 1457  2002  AL0        237042.0      AL
# 1960  2003  AL0        245608.0      AL
# 2463  2004  AL0        253974.0      AL

# %%
# year value count
final_age['year'] = final_age['year'].astype(str)
final_age['year'].value_counts()
# Out:
# 2006    390
# 2000    390
# 2015    390
# 2005    390
# 2007    390
# 2019    390
# 2002    390
# 2017    390
# 2020    390
# 2009    390
# 2004    390
# 2016    390
# 2013    390
# 2018    390
# 2010    390
# 2001    390
# 2014    390
# 2008    390
# 2012    390
# 2003    390
# 2011    390
# 2021     18
# Name: year, dtype: int64

# %% [markdown]
# Not much data for 2021. Hence, data for 2021 will be added to the 'population' dataframe. This is done by subsetting the data for 2020 and setting the year the 2021, and then concatenating the subset for 2020 with the original dataframe. That way data for the year 2021 is included in the data with the population figures of 2020.

# %%
# data for 2021
age_2021 = final_age[final_age['year'] == '2021']
age_2021.head()
# Out:
#      year    GEO  population_65+ country
# 378  2021  FI1D1         44806.0      FI
# 379  2021  FI1D2         62890.0      FI
# 380  2021  FI1D3         43343.0      FI
# 381  2021  FI1D5         16194.0      FI
# 382  2021  FI1D7         45909.0      FI

# %%
# drop few figures for 2021 to simplify merging, values from 2020 will be used
final_age = final_age[final_age['year'] != '2021']
final_age['year'].value_counts()
# Out:
# 2006    390
# 2004    390
# 2015    390
# 2005    390
# 2007    390
# 2019    390
# 2002    390
# 2017    390
# 2020    390
# 2009    390
# 2016    390
# 2000    390
# 2013    390
# 2018    390
# 2010    390
# 2001    390
# 2014    390
# 2008    390
# 2012    390
# 2003    390
# 2011    390
# Name: year, dtype: int64

# %%
age_2020 = final_age[final_age['year'] == '2020']
age_2020.head()
# Out:
#        year   GEO  population_65+ country
# 10511  2020   AL0        420036.0      AL
# 10512  2020  AL01        119241.0      AL
# 10513  2020  AL02        170897.0      AL
# 10514  2020  AL03        129898.0      AL
# 10515  2020   ALX             0.0      AL

# %%
# use values of 2020 for 2021
age_2020['year'] = '2021'
age_2020.head()
# Out:
# <ipython-input-59-9064fcf9306a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_2020['year'] = '2021'
#        year   GEO  population_65+ country
# 10511  2021   AL0        420036.0      AL
# 10512  2021  AL01        119241.0      AL
# 10513  2021  AL02        170897.0      AL
# 10514  2021  AL03        129898.0      AL
# 10515  2021   ALX             0.0      AL

# %%
# inspect shape
age_2020.shape
# Out:
# (390, 4)

# %%
# concatenate the frames containing information for population 65+
frames = [final_age, age_2020]
final_age = pd.concat(frames)
final_age['year'].value_counts()
# Out:
# 2006    390
# 2000    390
# 2015    390
# 2005    390
# 2007    390
# 2019    390
# 2002    390
# 2017    390
# 2020    390
# 2009    390
# 2004    390
# 2016    390
# 2013    390
# 2018    390
# 2021    390
# 2010    390
# 2001    390
# 2014    390
# 2008    390
# 2012    390
# 2003    390
# 2011    390
# Name: year, dtype: int64

# %% [markdown]
# The new dataframe consists data fro 2020 and 2021.

# %% [markdown]
# ## Merge population dataframes

# %%
# change type of column
population['year'] = population['year'].astype(str)
# merge population 65+ with overall population and density dataframe
population = population.merge(final_age, how='inner', on=['year','GEO'])
population
# Out:
#       year   GEO           GEO_LABEL    SEX    AGE    UNIT  population  \
# 0     2000   AL0           Shqipëria  Total  Total  Number   3063318.0
# 1     2001   AL0           Shqipëria  Total  Total  Number   3063318.0
# 2     2002   AL0           Shqipëria  Total  Total  Number   3057018.0
# 3     2003   AL0           Shqipëria  Total  Total  Number   3044993.0
# 4     2004   AL0           Shqipëria  Total  Total  Number   3034231.0
# ...    ...   ...                 ...    ...    ...     ...         ...
# 8460  2017  SK04  Východné Slovensko  Total  Total  Number   1620413.0
# 8461  2018  SK04  Východné Slovensko  Total  Total  Number   1623043.0
# 8462  2019  SK04  Východné Slovensko  Total  Total  Number   1625436.0
# 8463  2020  SK04  Východné Slovensko  Total  Total  Number   1627704.0
# 8464  2021  SK04  Východné Slovensko  Total  Total  Number   1627704.0
#
#       density  code_length country_x  population_65+ country_y
# 0       100.7            3        AL        237042.0        AL
# 1       100.7            3        AL        237042.0        AL
# 2       100.7            3        AL        237042.0        AL
# 3       100.7            3        AL        245608.0        AL
# 4       100.7            3        AL        253974.0        AL
# ...       ...          ...       ...             ...       ...
# 8460    103.6            4        SK        216823.0        SK
# 8461    103.8            4        SK        225172.0        SK
# 8462    103.9            4        SK        233178.0        SK
# 8463    103.9            4        SK        241682.0        SK
# 8464    103.9            4        SK        241682.0        SK
#
# [8465 rows x 12 columns]

# %%
# rename columns
population = population.drop(['SEX', 'AGE', 'UNIT', 'code_length', 'country_y'], axis=1)
population = population.rename(columns={'country_x': 'country'})
population.head()
# Out:
#    year  GEO  GEO_LABEL  population  density country  population_65+
# 0  2000  AL0  Shqipëria   3063318.0    100.7      AL        237042.0
# 1  2001  AL0  Shqipëria   3063318.0    100.7      AL        237042.0
# 2  2002  AL0  Shqipëria   3057018.0    100.7      AL        237042.0
# 3  2003  AL0  Shqipëria   3044993.0    100.7      AL        245608.0
# 4  2004  AL0  Shqipëria   3034231.0    100.7      AL        253974.0

# %%
# compute the share of population over the age of 65 in %
population['share_over_65'] = population['population_65+']/population['population']*100
population.head()
# Out:
#    year  GEO  GEO_LABEL  population  density country  population_65+  \
# 0  2000  AL0  Shqipëria   3063318.0    100.7      AL        237042.0
# 1  2001  AL0  Shqipëria   3063318.0    100.7      AL        237042.0
# 2  2002  AL0  Shqipëria   3057018.0    100.7      AL        237042.0
# 3  2003  AL0  Shqipëria   3044993.0    100.7      AL        245608.0
# 4  2004  AL0  Shqipëria   3034231.0    100.7      AL        253974.0
#
#    share_over_65
# 0       7.738080
# 1       7.738080
# 2       7.754027
# 3       8.065963
# 4       8.370292

# %%
# find regions with highest share of old people
population.sort_values(by='share_over_65', ascending=False)
# Out:
#       year    GEO GEO_LABEL  population  density country  population_65+  \
# 3717  2021  FI1D1       NaN    140587.0     10.1      FI         44123.0
# 3718  2021  FI1D1       NaN    142335.0     10.1      FI         44123.0
# 3716  2020  FI1D1       NaN    142335.0     10.1      FI         44123.0
# 3715  2019  FI1D1       NaN    144615.0     10.1      FI         43508.0
# 2287  2021   DED4  Chemnitz   1426380.0    219.9      DE        418482.0
# ...    ...    ...       ...         ...      ...     ...             ...
# 4762  2003   FRY5   Mayotte    223713.0    624.5      FR          5836.0
# 4761  2002   FRY5   Mayotte    223713.0    624.5      FR          5836.0
# 4760  2001   FRY5   Mayotte    223713.0    624.5      FR          5836.0
# 4759  2000   FRY5   Mayotte    223713.0    624.5      FR          5836.0
# 4768  2009   FRY5   Mayotte    223713.0    624.5      FR          5836.0
#
#       share_over_65
# 3717      31.384836
# 3718      30.999403
# 3716      30.999403
# 3715      30.085399
# 2287      29.338746
# ...             ...
# 4762       2.608700
# 4761       2.608700
# 4760       2.608700
# 4759       2.608700
# 4768       2.608700
#
# [8465 rows x 8 columns]

# %%
# no missing values recorded
filtered_df = population[population['share_over_65'].isnull()]
filtered_df.head()
# Out:
# Empty DataFrame
# Columns: [year, GEO, GEO_LABEL, population, density, country, population_65+, share_over_65]
# Index: []

# %%
# inspect mortality data
mortality
# Out:
#           TIME    GEO                                          GEO_LABEL  \
# 0      2000W01     BE                                            Belgium
# 1      2000W01    BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2      2000W01   BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 3      2000W01    BE2                                      Vlaams Gewest
# 4      2000W01   BE21                                    Prov. Antwerpen
# ...        ...    ...                                                ...
# 21019  2022W19  SE332                                                NaN
# 21020  2022W19  NO071                                                NaN
# 21021  2022W19  NO072                                                NaN
# 21022  2022W19  NO073                                                NaN
# 21023  2022W19  NO074                                                NaN
#
#        deaths country week_nr  year
# 0      2814.0      BE     W01  2000
# 1       298.0      BE     W01  2000
# 2       298.0      BE     W01  2000
# 3      1443.0      BE     W01  2000
# 4       439.0      BE     W01  2000
# ...       ...     ...     ...   ...
# 21019     NaN      SE     W19  2022
# 21020     NaN      NO     W19  2022
# 21021     NaN      NO     W19  2022
# 21022     NaN      NO     W19  2022
# 21023     NaN      NO     W19  2022
#
# [506016 rows x 7 columns]

# %%
# inspect population data
population
# Out:
#       year   GEO           GEO_LABEL  population  density country  \
# 0     2000   AL0           Shqipëria   3063318.0    100.7      AL
# 1     2001   AL0           Shqipëria   3063318.0    100.7      AL
# 2     2002   AL0           Shqipëria   3057018.0    100.7      AL
# 3     2003   AL0           Shqipëria   3044993.0    100.7      AL
# 4     2004   AL0           Shqipëria   3034231.0    100.7      AL
# ...    ...   ...                 ...         ...      ...     ...
# 8460  2017  SK04  Východné Slovensko   1620413.0    103.6      SK
# 8461  2018  SK04  Východné Slovensko   1623043.0    103.8      SK
# 8462  2019  SK04  Východné Slovensko   1625436.0    103.9      SK
# 8463  2020  SK04  Východné Slovensko   1627704.0    103.9      SK
# 8464  2021  SK04  Východné Slovensko   1627704.0    103.9      SK
#
#       population_65+  share_over_65
# 0           237042.0       7.738080
# 1           237042.0       7.738080
# 2           237042.0       7.754027
# 3           245608.0       8.065963
# 4           253974.0       8.370292
# ...              ...            ...
# 8460        216823.0      13.380725
# 8461        225172.0      13.873446
# 8462        233178.0      14.345566
# 8463        241682.0      14.848031
# 8464        241682.0      14.848031
#
# [8465 rows x 8 columns]

# %%
# change colkumn type
population['year'] = population['year'].astype(str)
# merge mortality with population
mort = mortality.merge(population, how='inner', on=['year','GEO'])
mort.head()
# Out:
#       TIME  GEO                                        GEO_LABEL_x  deaths  \
# 0  2000W01  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   298.0
# 1  2000W02  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   260.0
# 2  2000W03  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   281.0
# 3  2000W04  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   242.0
# 4  2000W05  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   245.0
#
#   country_x week_nr  year                                        GEO_LABEL_y  \
# 0        BE     W01  2000  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 1        BE     W02  2000  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2        BE     W03  2000  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 3        BE     W04  2000  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 4        BE     W05  2000  Région de Bruxelles-Capitale/Brussels Hoofdste...
#
#    population  density country_y  population_65+  share_over_65
# 0    959318.0   5974.3        BE        160908.0      16.773166
# 1    959318.0   5974.3        BE        160908.0      16.773166
# 2    959318.0   5974.3        BE        160908.0      16.773166
# 3    959318.0   5974.3        BE        160908.0      16.773166
# 4    959318.0   5974.3        BE        160908.0      16.773166

# %%
# drop and rename columns
mort = mort.drop(['GEO_LABEL_y', 'country_y'], axis=1)
mort = mort.rename(columns={'GEO_LABEL_x': 'GEO_LABEL', 'country_x': 'country'})
mort.head()
# Out:
#       TIME  GEO                                          GEO_LABEL  deaths  \
# 0  2000W01  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   298.0
# 1  2000W02  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   260.0
# 2  2000W03  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   281.0
# 3  2000W04  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   242.0
# 4  2000W05  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   245.0
#
#   country week_nr  year  population  density  population_65+  share_over_65
# 0      BE     W01  2000    959318.0   5974.3        160908.0      16.773166
# 1      BE     W02  2000    959318.0   5974.3        160908.0      16.773166
# 2      BE     W03  2000    959318.0   5974.3        160908.0      16.773166
# 3      BE     W04  2000    959318.0   5974.3        160908.0      16.773166
# 4      BE     W05  2000    959318.0   5974.3        160908.0      16.773166

# %%
# inspect shape
mort.shape
# Out:
# (386965, 11)

# %%
# getting relevant weeks (week 18 to week 39)
relevant_weeks = []
for i in range(18,41):
    strings = 'W{}'.format(i)
    relevant_weeks.append(strings)

# %%
# only keeping data from relevant weeks
mort = mort[mort['week_nr'].isin(relevant_weeks)]

# %%
# inspect shape
mort.shape
# Out:
# (170407, 11)

# %%
# get mortality per 100,000 per week
mort['death_p_100k'] = mort['deaths']/mort['population']*100000

# %%
# inspect data
mort.head(3)
# Out:
#        TIME  GEO                                          GEO_LABEL  deaths  \
# 17  2000W18  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   196.0
# 18  2000W19  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   172.0
# 19  2000W20  BE1  Région de Bruxelles-Capitale/Brussels Hoofdste...   158.0
#
#    country week_nr  year  population  density  population_65+  share_over_65  \
# 17      BE     W18  2000    959318.0   5974.3        160908.0      16.773166
# 18      BE     W19  2000    959318.0   5974.3        160908.0      16.773166
# 19      BE     W20  2000    959318.0   5974.3        160908.0      16.773166
#
#     death_p_100k
# 17     20.431181
# 18     17.929404
# 19     16.470034

# %%
# sort values
mort.sort_values(by=['death_p_100k'],ascending=False).head(10)
# Out:
#            TIME   GEO                      GEO_LABEL  deaths country week_nr  \
# 356758  2021W33  FRY1                     Guadeloupe   311.0      FR     W33
# 356759  2021W34  FRY1                     Guadeloupe   290.0      FR     W34
# 356811  2021W33  FRY2                     Martinique   219.0      FR     W33
# 356810  2021W32  FRY2                     Martinique   206.0      FR     W32
# 363337  2021W40  RO31                 Sud - Muntenia  1648.0      RO     W40
# 350508  2021W37  BG32             Severen tsentralen   439.0      BG     W37
# 363178  2021W40  RO21                       Nord-Est  1762.0      RO     W40
# 350511  2021W40  BG32             Severen tsentralen   427.0      BG     W40
# 363496  2021W40  RO41               Sud-Vest Oltenia  1039.0      RO     W40
# 366517  2021W40  RS22  Region Juzne i Istocne Srbije   802.0      RS     W40
#
#         year  population  density  population_65+  share_over_65  death_p_100k
# 356758  2021    412682.0    247.0         84319.0      20.431955     75.360689
# 356759  2021    412682.0    247.0         84319.0      20.431955     70.272025
# 356811  2021    359821.0    328.6         80327.0      22.324156     60.863596
# 356810  2021    359821.0    328.6         80327.0      22.324156     57.250689
# 363337  2021   2901376.0     86.1        607480.0      20.937652     56.800635
# 350508  2021    773450.0     53.1        188599.0      24.384123     56.758679
# 363178  2021   3184215.0     87.5        582256.0      18.285700     55.335459
# 350511  2021    773450.0     53.1        188599.0      24.384123     55.207189
# 363496  2021   1910409.0     66.9        400107.0      20.943526     54.386260
# 366517  2021   1482810.0     57.2        334023.0      22.526352     54.086498

# %%
# describe
mort['death_p_100k'].describe()
# Out:
# count    130874.000000
# mean         18.517425
# std           4.478693
# min           0.000000
# 25%          15.753118
# 50%          18.092744
# 75%          20.906112
# max          75.360689
# Name: death_p_100k, dtype: float64

# %%
mort['year'].value_counts()
# Out:
# 2021    8119
# 2010    7728
# 2008    7728
# 2016    7728
# 2012    7728
# 2013    7728
# 2019    7728
# 2014    7728
# 2017    7728
# 2018    7728
# 2005    7728
# 2004    7728
# 2015    7728
# 2007    7728
# 2020    7728
# 2001    7728
# 2009    7728
# 2006    7728
# 2002    7728
# 2003    7728
# 2000    7728
# 2011    7728
# Name: year, dtype: int64

# %%
# find rows with missing values in mortality
filtered_df = mort[mort['death_p_100k'].isnull()]
filtered_df
# Out:
#            TIME    GEO GEO_LABEL  deaths country week_nr  year  population  \
# 1161    2000W18    CZ0     Cesko     NaN      CZ     W18  2000  10278098.0
# 1162    2000W19    CZ0     Cesko     NaN      CZ     W19  2000  10278098.0
# 1163    2000W20    CZ0     Cesko     NaN      CZ     W20  2000  10278098.0
# 1164    2000W21    CZ0     Cesko     NaN      CZ     W21  2000  10278098.0
# 1165    2000W22    CZ0     Cesko     NaN      CZ     W22  2000  10278098.0
# ...         ...    ...       ...     ...     ...     ...   ...         ...
# 386934  2021W38  NO073       NaN     NaN      NO     W38  2021     75472.0
# 386935  2021W39  NO073       NaN     NaN      NO     W39  2021     75472.0
# 386936  2021W39  NO073       NaN     NaN      NO     W39  2021     75472.0
# 386937  2021W40  NO073       NaN     NaN      NO     W40  2021     75472.0
# 386938  2021W40  NO073       NaN     NaN      NO     W40  2021     75472.0
#
#         density  population_65+  share_over_65  death_p_100k
# 1161      132.7       1418078.0      13.797086           NaN
# 1162      132.7       1418078.0      13.797086           NaN
# 1163      132.7       1418078.0      13.797086           NaN
# 1164      132.7       1418078.0      13.797086           NaN
# 1165      132.7       1418078.0      13.797086           NaN
# ...         ...             ...            ...           ...
# 386934      1.6         13963.0      18.500901           NaN
# 386935      1.6         13963.0      18.500901           NaN
# 386936      1.6         13963.0      18.500901           NaN
# 386937      1.6         13963.0      18.500901           NaN
# 386938      1.6         13963.0      18.500901           NaN
#
# [39533 rows x 12 columns]

# %%
filtered_df['GEO'].unique()
# Out:
# array(['CZ0', 'CZ01', 'CZ02', 'CZ03', 'CZ04', 'CZ05', 'CZ06', 'CZ07',
#        'CZ08', 'DK0', 'DK01', 'DK02', 'DK03', 'DK04', 'DK05', 'IE0',
#        'EL3', 'EL30', 'EL4', 'EL41', 'EL42', 'EL43', 'EL5', 'EL51',
#        'EL52', 'EL53', 'EL54', 'EL6', 'EL61', 'EL62', 'EL63', 'EL64',
#        'EL65', 'FR1', 'FR10', 'FRB', 'FRB0', 'FRC', 'FRC1', 'FRC2', 'FRD',
#        'FRD1', 'FRD2', 'FRE', 'FRE1', 'FRE2', 'FRF', 'FRF1', 'FRF2',
#        'FRF3', 'FRG', 'FRG0', 'FRH', 'FRH0', 'FRI', 'FRI1', 'FRI2',
#        'FRI3', 'FRJ', 'FRJ1', 'FRJ2', 'FRK', 'FRK1', 'FRK2', 'FRL',
#        'FRL0', 'FRM', 'FRM0', 'FRY1', 'FRY2', 'FRY3', 'FRY4', 'FRY5',
#        'ITC', 'ITC1', 'ITC2', 'ITC3', 'ITC4', 'ITH', 'ITH1', 'ITH2',
#        'ITH3', 'ITH4', 'ITH5', 'ITI', 'ITI1', 'ITI2', 'ITI3', 'ITI4',
#        'ITF', 'ITF1', 'ITF2', 'ITF3', 'ITF4', 'ITF5', 'ITF6', 'ITG',
#        'ITG1', 'ITG2', 'CY0', 'CY00', 'MT0', 'MT00', 'NL1', 'NL11',
#        'NL12', 'NL13', 'NL2', 'NL21', 'NL22', 'NL23', 'NL3', 'NL31',
#        'NL32', 'NL33', 'NL34', 'NL4', 'NL41', 'NL42', 'RO1', 'RO11',
#        'RO12', 'RO2', 'RO21', 'RO22', 'RO3', 'RO31', 'RO32', 'RO4',
#        'RO41', 'RO42', 'ME0', 'ME00', 'AL0', 'AL01', 'AL02', 'AL03',
#        'NO01', 'NO03', 'NO04', 'NO05', 'NO072', 'NO073'], dtype=object)

# %%
filtered_df['code_length'] = filtered_df.GEO.str.len()
filtered_df['code_length'].value_counts()
# Out:
# <ipython-input-85-15fa3e8f32be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['code_length'] = filtered_df.GEO.str.len()
# 4    28360
# 3    11089
# 5       84
# Name: code_length, dtype: int64

# %%
# show all columns with missing values
mort.columns[mort.isna().any()].tolist()
# Out:
# ['GEO_LABEL', 'deaths', 'death_p_100k']

# %%
# filter all instances with missing mortality figures
null_data = mort[mort['deaths'].isnull()]
null_data.shape
# Out:
# (39533, 12)

# %%
# unique regions
null_data['GEO'].unique()
# Out:
# array(['CZ0', 'CZ01', 'CZ02', 'CZ03', 'CZ04', 'CZ05', 'CZ06', 'CZ07',
#        'CZ08', 'DK0', 'DK01', 'DK02', 'DK03', 'DK04', 'DK05', 'IE0',
#        'EL3', 'EL30', 'EL4', 'EL41', 'EL42', 'EL43', 'EL5', 'EL51',
#        'EL52', 'EL53', 'EL54', 'EL6', 'EL61', 'EL62', 'EL63', 'EL64',
#        'EL65', 'FR1', 'FR10', 'FRB', 'FRB0', 'FRC', 'FRC1', 'FRC2', 'FRD',
#        'FRD1', 'FRD2', 'FRE', 'FRE1', 'FRE2', 'FRF', 'FRF1', 'FRF2',
#        'FRF3', 'FRG', 'FRG0', 'FRH', 'FRH0', 'FRI', 'FRI1', 'FRI2',
#        'FRI3', 'FRJ', 'FRJ1', 'FRJ2', 'FRK', 'FRK1', 'FRK2', 'FRL',
#        'FRL0', 'FRM', 'FRM0', 'FRY1', 'FRY2', 'FRY3', 'FRY4', 'FRY5',
#        'ITC', 'ITC1', 'ITC2', 'ITC3', 'ITC4', 'ITH', 'ITH1', 'ITH2',
#        'ITH3', 'ITH4', 'ITH5', 'ITI', 'ITI1', 'ITI2', 'ITI3', 'ITI4',
#        'ITF', 'ITF1', 'ITF2', 'ITF3', 'ITF4', 'ITF5', 'ITF6', 'ITG',
#        'ITG1', 'ITG2', 'CY0', 'CY00', 'MT0', 'MT00', 'NL1', 'NL11',
#        'NL12', 'NL13', 'NL2', 'NL21', 'NL22', 'NL23', 'NL3', 'NL31',
#        'NL32', 'NL33', 'NL34', 'NL4', 'NL41', 'NL42', 'RO1', 'RO11',
#        'RO12', 'RO2', 'RO21', 'RO22', 'RO3', 'RO31', 'RO32', 'RO4',
#        'RO41', 'RO42', 'ME0', 'ME00', 'AL0', 'AL01', 'AL02', 'AL03',
#        'NO01', 'NO03', 'NO04', 'NO05', 'NO072', 'NO073'], dtype=object)

# %%
# inspect data
null_data
# Out:
#            TIME    GEO GEO_LABEL  deaths country week_nr  year  population  \
# 1161    2000W18    CZ0     Cesko     NaN      CZ     W18  2000  10278098.0
# 1162    2000W19    CZ0     Cesko     NaN      CZ     W19  2000  10278098.0
# 1163    2000W20    CZ0     Cesko     NaN      CZ     W20  2000  10278098.0
# 1164    2000W21    CZ0     Cesko     NaN      CZ     W21  2000  10278098.0
# 1165    2000W22    CZ0     Cesko     NaN      CZ     W22  2000  10278098.0
# ...         ...    ...       ...     ...     ...     ...   ...         ...
# 386934  2021W38  NO073       NaN     NaN      NO     W38  2021     75472.0
# 386935  2021W39  NO073       NaN     NaN      NO     W39  2021     75472.0
# 386936  2021W39  NO073       NaN     NaN      NO     W39  2021     75472.0
# 386937  2021W40  NO073       NaN     NaN      NO     W40  2021     75472.0
# 386938  2021W40  NO073       NaN     NaN      NO     W40  2021     75472.0
#
#         density  population_65+  share_over_65  death_p_100k
# 1161      132.7       1418078.0      13.797086           NaN
# 1162      132.7       1418078.0      13.797086           NaN
# 1163      132.7       1418078.0      13.797086           NaN
# 1164      132.7       1418078.0      13.797086           NaN
# 1165      132.7       1418078.0      13.797086           NaN
# ...         ...             ...            ...           ...
# 386934      1.6         13963.0      18.500901           NaN
# 386935      1.6         13963.0      18.500901           NaN
# 386936      1.6         13963.0      18.500901           NaN
# 386937      1.6         13963.0      18.500901           NaN
# 386938      1.6         13963.0      18.500901           NaN
#
# [39533 rows x 12 columns]

# %% [markdown]
# If data is missing on NUTS2 level, it will be imputed by data on the NUTS1 level for small countries

# %%
# get code length
mort['code_length'] = mort.GEO.str.len()

# %%
# filter for NUTS 1
NUTS1 = mort[mort['code_length'] == 3]
NUTS1 = NUTS1[['death_p_100k', 'GEO', 'TIME']]

# %%
# filter for NUTS2
NUTS2 = mort[mort['code_length'] == 4]
NUTS2['NUTS1'] = NUTS2['GEO'].str[:3]
# merge NUTS1 and NUTS2 subdata
NUTS2 = NUTS2.merge(NUTS1, left_on=['NUTS1', 'TIME'], right_on=['GEO', 'TIME'])
NUTS2 = NUTS2.drop(['NUTS1', 'GEO_y'],1)
NUTS2 = NUTS2.rename(columns={'death_p_100k_x': 'death_p_100k', 'death_p_100k_y': 'death_p_100k_NUTS1'})
NUTS2
# Out:
# <ipython-input-95-c6eecb937cf7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NUTS2['NUTS1'] = NUTS2['GEO'].str[:3]
#            TIME GEO_x                                          GEO_LABEL  \
# 0       2000W18  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 1       2000W19  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2       2000W20  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 3       2000W21  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 4       2000W22  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# ...         ...   ...                                                ...
# 108279  2021W38  RS22                      Region Juzne i Istocne Srbije
# 108280  2021W39  RS21                   Region Sumadije i Zapadne Srbije
# 108281  2021W39  RS22                      Region Juzne i Istocne Srbije
# 108282  2021W40  RS21                   Region Sumadije i Zapadne Srbije
# 108283  2021W40  RS22                      Region Juzne i Istocne Srbije
#
#         deaths country week_nr  year  population  density  population_65+  \
# 0        196.0      BE     W18  2000    959318.0   5974.3        160908.0
# 1        172.0      BE     W19  2000    959318.0   5974.3        160908.0
# 2        158.0      BE     W20  2000    959318.0   5974.3        160908.0
# 3        193.0      BE     W21  2000    959318.0   5974.3        160908.0
# 4        170.0      BE     W22  2000    959318.0   5974.3        160908.0
# ...        ...     ...     ...   ...         ...      ...             ...
# 108279   540.0      RS     W38  2021   1482810.0     57.2        334023.0
# 108280   999.0      RS     W39  2021   1900429.0     72.4        412962.0
# 108281   752.0      RS     W39  2021   1482810.0     57.2        334023.0
# 108282  1006.0      RS     W40  2021   1900429.0     72.4        412962.0
# 108283   802.0      RS     W40  2021   1482810.0     57.2        334023.0
#
#         share_over_65  death_p_100k  code_length  death_p_100k_NUTS1
# 0           16.773166     20.431181            4           20.431181
# 1           16.773166     17.929404            4           17.929404
# 2           16.773166     16.470034            4           16.470034
# 3           16.773166     20.118459            4           20.118459
# 4           16.773166     17.720923            4           17.720923
# ...               ...           ...          ...                 ...
# 108279      22.526352     36.417343            4           40.109493
# 108280      21.729936     52.567078            4           51.755138
# 108281      22.526352     50.714522            4           51.755138
# 108282      21.729936     52.935416            4           53.439914
# 108283      22.526352     54.086498            4           53.439914
#
# [108284 rows x 14 columns]

# %%
# show which NUTS2 regions do not have mortality figures whilst the NUTS 1 regions has
filtered_df = NUTS2[(NUTS2['death_p_100k'].isnull()) & (NUTS2['death_p_100k_NUTS1'] > 0)]
filtered_df
# Out:
#            TIME GEO_x                                    GEO_LABEL  deaths  \
# 107792  2021W20  NO01   Oslo og Akershus (statistical region 2016)     NaN
# 107794  2021W20  NO03      Sør-Østlandet (statistical region 2016)     NaN
# 107795  2021W20  NO04  Agder og Rogaland (statistical region 2016)     NaN
# 107796  2021W20  NO05         Vestlandet (statistical region 2016)     NaN
# 107799  2021W21  NO01   Oslo og Akershus (statistical region 2016)     NaN
# ...         ...   ...                                          ...     ...
# 107929  2021W39  NO05         Vestlandet (statistical region 2016)     NaN
# 107932  2021W40  NO01   Oslo og Akershus (statistical region 2016)     NaN
# 107934  2021W40  NO03      Sør-Østlandet (statistical region 2016)     NaN
# 107935  2021W40  NO04  Agder og Rogaland (statistical region 2016)     NaN
# 107936  2021W40  NO05         Vestlandet (statistical region 2016)     NaN
#
#        country week_nr  year  population  density  population_65+  \
# 107792      NO     W20  2021   1326682.0    259.8        188663.0
# 107794      NO     W20  2021   1011472.0     29.4        198487.0
# 107795      NO     W20  2021    787123.0     32.2        126309.0
# 107796      NO     W20  2021    905335.0     19.1        164606.0
# 107799      NO     W21  2021   1326682.0    259.8        188663.0
# ...        ...     ...   ...         ...      ...             ...
# 107929      NO     W39  2021    905335.0     19.1        164606.0
# 107932      NO     W40  2021   1326682.0    259.8        188663.0
# 107934      NO     W40  2021   1011472.0     29.4        198487.0
# 107935      NO     W40  2021    787123.0     32.2        126309.0
# 107936      NO     W40  2021    905335.0     19.1        164606.0
#
#         share_over_65  death_p_100k  code_length  death_p_100k_NUTS1
# 107792      14.220665           NaN            4           13.767843
# 107794      19.623578           NaN            4           13.767843
# 107795      16.046920           NaN            4           13.767843
# 107796      18.181778           NaN            4           13.767843
# 107799      14.220665           NaN            4           13.618800
# ...               ...           ...          ...                 ...
# 107929      18.181778           NaN            4           14.978817
# 107932      14.220665           NaN            4           15.016078
# 107934      19.623578           NaN            4           15.016078
# 107935      16.046920           NaN            4           15.016078
# 107936      18.181778           NaN            4           15.016078
#
# [84 rows x 14 columns]

# %% [markdown]
# Regions in Souther Norway do not have NUTS2 mortality but NUTS 1 mortality.

# %%
# impute NaN for regions in Norway with no NUTS 2 mortality with NUTS 1 mortality
NUTS2['death_p_100k'] = NUTS2['death_p_100k'].fillna(NUTS2['death_p_100k_NUTS1'])
filtered_df = NUTS2[(NUTS2['death_p_100k'].isnull()) & (NUTS2['death_p_100k_NUTS1'] > 0)]
filtered_df
# Out:
# Empty DataFrame
# Columns: [TIME, GEO_x, GEO_LABEL, deaths, country, week_nr, year, population, density, population_65+, share_over_65, death_p_100k, code_length, death_p_100k_NUTS1]
# Index: []

# %%
# drop unneccessary columns
NUTS2 = NUTS2.drop(['death_p_100k_NUTS1', 'code_length'],1)
NUTS2 = NUTS2.rename(columns={'GEO_x': 'GEO'})
NUTS2
# Out:
#            TIME   GEO                                          GEO_LABEL  \
# 0       2000W18  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 1       2000W19  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2       2000W20  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 3       2000W21  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 4       2000W22  BE10  Région de Bruxelles-Capitale/Brussels Hoofdste...
# ...         ...   ...                                                ...
# 108279  2021W38  RS22                      Region Juzne i Istocne Srbije
# 108280  2021W39  RS21                   Region Sumadije i Zapadne Srbije
# 108281  2021W39  RS22                      Region Juzne i Istocne Srbije
# 108282  2021W40  RS21                   Region Sumadije i Zapadne Srbije
# 108283  2021W40  RS22                      Region Juzne i Istocne Srbije
#
#         deaths country week_nr  year  population  density  population_65+  \
# 0        196.0      BE     W18  2000    959318.0   5974.3        160908.0
# 1        172.0      BE     W19  2000    959318.0   5974.3        160908.0
# 2        158.0      BE     W20  2000    959318.0   5974.3        160908.0
# 3        193.0      BE     W21  2000    959318.0   5974.3        160908.0
# 4        170.0      BE     W22  2000    959318.0   5974.3        160908.0
# ...        ...     ...     ...   ...         ...      ...             ...
# 108279   540.0      RS     W38  2021   1482810.0     57.2        334023.0
# 108280   999.0      RS     W39  2021   1900429.0     72.4        412962.0
# 108281   752.0      RS     W39  2021   1482810.0     57.2        334023.0
# 108282  1006.0      RS     W40  2021   1900429.0     72.4        412962.0
# 108283   802.0      RS     W40  2021   1482810.0     57.2        334023.0
#
#         share_over_65  death_p_100k
# 0           16.773166     20.431181
# 1           16.773166     17.929404
# 2           16.773166     16.470034
# 3           16.773166     20.118459
# 4           16.773166     17.720923
# ...               ...           ...
# 108279      22.526352     36.417343
# 108280      21.729936     52.567078
# 108281      22.526352     50.714522
# 108282      21.729936     52.935416
# 108283      22.526352     54.086498
#
# [108284 rows x 12 columns]

# %% [markdown]
# #### No indication of any invalid symbols in any of the numeric column is found.

# %%
# inspect shape
mort.shape
# Out:
# (170407, 13)

# %%
mort['death_p_100k'].isna().sum()
# Out:
# 39533

# %%
# remove all NUTS2 regions from mort dataframe
mort = mort[mort['code_length'] != 4]
# cancatenate mort dataframe with all NUTS2 regions including those that have been imputed
frames = [mort,NUTS2]
mort = pd.concat(frames)
mort.shape
# Out:
# (167877, 13)

# %%
# slightly reduced number of NaN
mort['death_p_100k'].isna().sum()
# Out:
# 37931

# %%
# count of NUTS regions
mort['GEO'].value_counts().head(25)
# Out:
# SE331    529
# FI1D1    529
# FI1D2    529
# SE321    529
# FI1D5    529
# FI1D8    529
# FI1D9    529
# SE313    529
# NO073    529
# SE311    529
# SE332    529
# FI1D3    529
# NO072    529
# NO071    529
# SE322    529
# SE312    529
# FI1D7    529
# CH06     506
# ES6      506
# FRI2     506
# AT31     506
# BE1      506
# ITC4     506
# EL3      506
# CH03     506
# Name: GEO, dtype: int64

# %%
# dropping potential duplicates
mort = mort.drop_duplicates(subset=['GEO', 'TIME'], keep='first')
mort['GEO'].value_counts()
# Out:
# ITH     506
# ES12    506
# SK0     506
# RS22    506
# DE1     506
#        ...
# NL34    506
# NL4     506
# BE10    506
# PL43    506
# PL71    506
# Name: GEO, Length: 331, dtype: int64

# %%
# write to csv
mort.to_csv('Mortality1.csv')
